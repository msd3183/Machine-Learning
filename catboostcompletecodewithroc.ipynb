# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.neighbors import LocalOutlierFactor
from scipy.stats import probplot
from scipy.stats import zscore

# %%
df=pd.read_csv(r"C:\Users\Asus\Downloads\MiniProject\water_dataX.csv",encoding= 'unicode_escape')
df.shape
# Out:
# (1991, 12)

# %%
df=df.iloc[0:1900,:]
df.shape
# Out:
# (1900, 12)

# %%
df.dtypes
# Out:
# STATION CODE                        object
# LOCATIONS                           object
# STATE                               object
# Temp                                object
# D.O. (mg/l)                         object
# PH                                  object
# CONDUCTIVITY (µmhos/cm)             object
# B.O.D. (mg/l)                       object
# NITRATENAN N+ NITRITENANN (mg/l)    object
# FECAL COLIFORM (MPN/100ml)          object
# TOTAL COLIFORM (MPN/100ml)Mean      object
# year                                 int64
# dtype: object

# %%
df.head()
# Out:
#   STATION CODE                                          LOCATIONS  \
# 0         1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN
# 1         1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...
# 2         1475                                ZUARI AT PANCHAWADI
# 3         3181                        RIVER ZUARI AT BORIM BRIDGE
# 4         3182                       RIVER ZUARI AT MARCAIM JETTY
#
#          STATE  Temp D.O. (mg/l)   PH CONDUCTIVITY (µmhos/cm) B.O.D. (mg/l)  \
# 0  DAMAN & DIU  30.6         6.7  7.5                     203           NAN
# 1          GOA  29.8         5.7  7.2                     189             2
# 2          GOA  29.5         6.3  6.9                     179           1.7
# 3          GOA  29.7         5.8  6.9                      64           3.8
# 4          GOA  29.5         5.8  7.3                      83           1.9
#
#   NITRATENAN N+ NITRITENANN (mg/l) FECAL COLIFORM (MPN/100ml)  \
# 0                              0.1                         11
# 1                              0.2                       4953
# 2                              0.1                       3243
# 3                              0.5                       5382
# 4                              0.4                       3428
#
#   TOTAL COLIFORM (MPN/100ml)Mean  year
# 0                             27  2014
# 1                           8391  2014
# 2                           5330  2014
# 3                           8443  2014
# 4                           5500  2014

# %%
df = df.rename(columns={"D.O. (mg/l)": "DO", "CONDUCTIVITY (µmhos/cm)": "Conductivity", "B.O.D. (mg/l)": "BOD", "NITRATENAN N+ NITRITENANN (mg/l)": "NI", "FECAL COLIFORM (MPN/100ml)": "Fec_col", "TOTAL COLIFORM (MPN/100ml)Mean": "Tot_col"})

# %%
def convert_to_numeric(df):
    num_col = df.shape[1]
    # Start from index 3
    for index in range(3, num_col):
        col_name = df.iloc[:, index].name
        df[col_name] = pd.to_numeric(df[col_name], errors="coerce")
    return df

df = convert_to_numeric(df)
df.dtypes
# Out:
# STATION CODE     object
# LOCATIONS        object
# STATE            object
# Temp            float64
# DO              float64
# PH              float64
# Conductivity    float64
# BOD             float64
# NI              float64
# Fec_col         float64
# Tot_col         float64
# year              int64
# dtype: object

# %%
def convert_to_nan(df):
    n_col = df.shape[1]
    for index in range(n_col):
        df.iloc[:, index]  = df.iloc[:, index].replace("NAN", np.nan)
    return df

df = convert_to_nan(df)

# %%
df.isnull().sum().sort_values()
# Out:
# year              0
# PH                7
# Conductivity     24
# DO               30
# BOD              42
# Temp             89
# STATION CODE    120
# Tot_col         130
# LOCATIONS       183
# NI              189
# Fec_col         280
# STATE           670
# dtype: int64

# %%
df_num = df.select_dtypes(exclude="object")
df_num_col = df_num.columns
imputer = SimpleImputer(strategy="median")

df_num = imputer.fit_transform(df_num)
df_num = pd.DataFrame(df_num, columns=df_num_col)

# %%
df_cat = df.select_dtypes(include="object")
df_cat.isnull().sum()
# Out:
# STATION CODE    120
# LOCATIONS       183
# STATE           670
# dtype: int64

# %%
pd.set_option('mode.chained_assignment', None)
df_cat_copy = df_cat.copy()

df_cat_copy[df_cat_copy["STATION CODE"] == "1330"]
# Station Code with value 1330 will have Location - TAMBIRAPARANI which belongs in STATE - TAMIL NADU
# I can replace all the NAN occurences in STATE with TAMILNADU
df_cat_copy["STATE"][df_cat_copy["STATION CODE"] == "1330"] = df_cat_copy["STATE"][df_cat_copy["STATION CODE"] == "1330"].fillna("TAMILNADU")

df_cat_copy[df_cat_copy["STATION CODE"] == "1330"]
# Out:
#      STATION CODE                                LOCATIONS  \
# 166          1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU
# 424          1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU
# 677          1330             TAMBIRAPARANI AT ARUMUGANERI
# 1168         1330             TAMBIRAPARANI AT ARUMUGANERI
# 1351         1330                                      NaN
# 1513         1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU
# 1626         1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU
# 1745         1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU
#
#                                         STATE
# 166                                 TAMILNADU
# 424                                 TAMILNADU
# 677                                 TAMILNADU
# 1168                                TAMILNADU
# 1351  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU
# 1513                                TAMILNADU
# 1626                                TAMILNADU
# 1745                                TAMILNADU

# %%
def fill_locations(df_cat):
    location_null = df_cat[df_cat["LOCATIONS"].isnull()]
    location_null_indices = location_null.index
    for index in location_null_indices:
        state_value = location_null["STATE"][index]
        location_null["LOCATIONS"][index] = state_value
        location_null["STATE"][index] = np.nan
    df_cat[df_cat["LOCATIONS"].isnull()] = location_null
    return

fill_locations(df_cat_copy)
df_cat_copy[df_cat_copy["STATION CODE"] == "1330"]
# Out:
#      STATION CODE                                LOCATIONS      STATE
# 166          1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU
# 424          1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU
# 677          1330             TAMBIRAPARANI AT ARUMUGANERI  TAMILNADU
# 1168         1330             TAMBIRAPARANI AT ARUMUGANERI  TAMILNADU
# 1351         1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU        NaN
# 1513         1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU
# 1626         1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU
# 1745         1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU

# %%
df_cat_copy[df_cat_copy["LOCATIONS"] == "TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU"]
# Out:
#      STATION CODE                                LOCATIONS      STATE
# 166          1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU
# 424          1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU
# 1351         1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU        NaN
# 1513         1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU
# 1626         1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU
# 1745         1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU
# 1896          NaN  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU        NaN

# %%
def fill_code(df_cat):
    station_null = df_cat[df_cat["STATION CODE"].isnull()]
    station_null_indices = station_null.index
    for index in station_null_indices:
        stat_code = np.nan
        location_index = station_null["LOCATIONS"][index]
        code_at_location = df_cat["STATION CODE"][df_cat["LOCATIONS"] == location_index]
        for index_code in code_at_location.index:
            if (code_at_location[index_code] != np.nan):
                stat_code = code_at_location[index_code]
                break
        station_null["STATION CODE"][index] = stat_code
    df_cat[df_cat["STATION CODE"].isnull()] = station_null
    return

fill_code(df_cat_copy)
df_cat_copy[df_cat_copy["LOCATIONS"] == "TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU"]
# Out:
#      STATION CODE                                LOCATIONS      STATE
# 166          1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU
# 424          1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU
# 1351         1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU        NaN
# 1513         1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU
# 1626         1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU
# 1745         1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU
# 1896         1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU        NaN

# %%
def fill_state(df_cat):
    station_code = df_cat["STATION CODE"].unique()
    for index in range(station_code.shape[0]):
        if (station_code[index] != np.nan):
            df_state = df_cat["STATE"][df_cat["STATION CODE"] == station_code[index]] 
            state_values = df_cat["STATE"][df_cat["STATION CODE"] == station_code[index]]
            state = np.nan
            for index_state in range(state_values.shape[0]):
                if (state_values.iloc[index_state] != np.nan):
                    state = state_values.iloc[index_state]
                    break
            df_state_fill = df_state.fillna(state) 
            df_cat["STATE"][df_cat["STATION CODE"] == station_code[index]] = df_state_fill
    return
fill_state(df_cat_copy)
df_cat_copy[df_cat_copy["STATION CODE"] == "1330"]
# Out:
#      STATION CODE                                LOCATIONS      STATE
# 166          1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU
# 424          1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU
# 677          1330             TAMBIRAPARANI AT ARUMUGANERI  TAMILNADU
# 1168         1330             TAMBIRAPARANI AT ARUMUGANERI  TAMILNADU
# 1351         1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU
# 1513         1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU
# 1626         1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU
# 1745         1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU
# 1896         1330  TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU  TAMILNADU

# %%
df_cat_copy.isnull().sum()
# Out:
# STATION CODE     4
# LOCATIONS        2
# STATE           12
# dtype: int64

# %%
df_cat_copy[df_cat_copy["STATE"].isnull()]
# Out:
#      STATION CODE                                          LOCATIONS STATE
# 260           NaN                                                NaN   NaN
# 431           NaN                                                NaN   NaN
# 1106         1207                              KABBANI AT MUTHANKARA   NaN
# 1107         1208                             BHAVANI AT ELACHIVAZHY   NaN
# 1650         2047                 NNANCHOE (ATTAWA CHOE), CHANDIGARH   NaN
# 1651         2048                         PATIALA KI RAO, CHANDIGARH   NaN
# 1652         2049                            SUKHNA CHOE, CHANDIGARH   NaN
# 1770         2047                             NNANCHOE (ATTAWA CHOE)   NaN
# 1771         2048                                     PATIALA KI RAO   NaN
# 1772         2049                                        SUKHNA CHOE   NaN
# 1784          NaN   DAMANGANGA  AFTER CONFL. OF PIPARIA DRAIN, DAMAN   NaN
# 1785          NaN  DAMANGANGA AT CIRCUIT HOUSE, SILVASA, DADRA AN...   NaN

# %%
df_cat_copy["STATE"][1106] = "KERALA"
df_cat_copy["STATE"][1107] = "KERALA"
df_cat_copy["STATE"][1650] = "CHANDIGARH"
df_cat_copy["STATE"][1651] = "CHANDIGARH"
df_cat_copy["STATE"][1652] = "CHANDIGARH"
df_cat_copy["STATE"][1770] = "CHANDIGARH"
df_cat_copy["STATE"][1771] = "CHANDIGARH"
df_cat_copy["STATE"][1772] = "CHANDIGARH"
df_cat_copy["STATE"][1784] = "DAMAN & DIU"
df_cat_copy["STATE"][1785] = "DAMAN & DIU"
df_cat_copy["STATION CODE"][1784] = "0000" # I am setting this according to myself
df_cat_copy["STATION CODE"][1785] = "0000"

# %%
df_cat = df_cat_copy
df_cat.isnull().sum()
# Out:
# STATION CODE    2
# LOCATIONS       2
# STATE           2
# dtype: int64

# %%
df_num.isnull().sum()
# Out:
# Temp            0
# DO              0
# PH              0
# Conductivity    0
# BOD             0
# NI              0
# Fec_col         0
# Tot_col         0
# year            0
# dtype: int64

# %%
df_final = pd.concat([df_cat, df_num], axis=1)
df_final.isnull().sum()
# Out:
# STATION CODE    2
# LOCATIONS       2
# STATE           2
# Temp            0
# DO              0
# PH              0
# Conductivity    0
# BOD             0
# NI              0
# Fec_col         0
# Tot_col         0
# year            0
# dtype: int64

# %%
df_null = df_final[(df_final["STATION CODE"].isnull()) & (df_final["LOCATIONS"].isnull()) & (df_final["STATE"].isnull())]
df_null_indices = df_null.index
df_final.drop(df_null_indices, axis=0, inplace=True)
df_null
# Out:
#     STATION CODE LOCATIONS STATE  Temp   DO   PH  Conductivity     BOD    NI  \
# 260          NaN       NaN   NaN  27.0  6.7  7.3         198.0  1.8965  0.52
# 431          NaN       NaN   NaN  27.0  6.7  7.3         198.0  1.8965  0.52
#
#      Fec_col  Tot_col    year
# 260    233.0    465.0  2013.0
# 431    233.0    465.0  2013.0

# %%
df_num_final = df_final.select_dtypes(exclude="object")
df_num_final_norm = zscore(df_num_final, axis=0)


def indices_of_greater_than_3(df_norm):
    indices_arr = []
    n_col = df_norm.shape[1]
    for index in range(n_col):
        col_index = df_norm.iloc[: ,index]
        greater_than_3 = df_norm[col_index > 3]
        greater_than_3_index = greater_than_3.index
        indices_arr.extend(greater_than_3_index)
    return indices_arr

indices_arr = indices_of_greater_than_3(df_num_final_norm)
print("Number of outliers using Z-Score method-",len(indices_arr))
df_final.iloc[indices_arr, :]
# Out:
# Number of outliers using Z-Score method- 125
#     STATION CODE                                          LOCATIONS  \
# 741         2880                          NAMBUL RIVER AT BISHNUPUR
# 745         2856                 THOUBAL RIVER AT YAIRIPOK, THOUBAL
# 37          2671  KUNDALIKA RIVER NEAR SALAV BRIDGE (SALINA ZONE...
# 88          2294                          R KALLAI AT KALLAI BRIDGE
# 108         2304                             R MOGRAL AT MOGRAL BR.
# ..           ...                                                ...
# 432         1023  GHAGGAR AT MUBARAKPUR REST HOUSE (PATIALA), PU...
# 685         1023         GHAGGAR AT MUBARAKPUR REST HOUSE (PATIALA)
# 172         3023  VASISTA AT SALEM, D/S OF SAGO INDUSRIES EFFLUE...
# 432         1023  GHAGGAR AT MUBARAKPUR REST HOUSE (PATIALA), PU...
# 685         1023         GHAGGAR AT MUBARAKPUR REST HOUSE (PATIALA)
#
#            STATE  Temp   DO   PH  Conductivity    BOD    NI      Fec_col  \
# 741      MANIPUR  28.0  8.2  7.6         112.0    2.1  0.52        233.0
# 745      MANIPUR  30.0  9.3  7.6         193.0    2.3  0.52        233.0
# 37   MAHARASHTRA  25.3  5.3  7.7       24062.0    9.9  1.20        156.0
# 88        KERALA  26.3  3.7  7.7       32005.0    1.2  0.90      40000.0
# 108       KERALA  30.0  5.6  7.2       24360.0    2.1  0.30         92.0
# ..           ...   ...  ...  ...           ...    ...   ...          ...
# 432       PUNJAB  23.3  5.5  7.2         636.0    9.7  4.00       1328.0
# 685       PUNJAB  21.0  5.5  7.4         635.0    8.8  5.08       1400.0
# 172    TAMILNADU  24.3  0.9  7.6        2039.0  104.5  0.90  272521616.0
# 432       PUNJAB  23.3  5.5  7.2         636.0    9.7  4.00       1328.0
# 685       PUNJAB  21.0  5.5  7.4         635.0    8.8  5.08       1400.0
#
#          Tot_col    year
# 741         31.0  2012.0
# 745         41.0  2012.0
# 37         304.0  2014.0
# 88       60392.0  2014.0
# 108        447.0  2014.0
# ..           ...     ...
# 432       4975.0  2013.0
# 685       5500.0  2012.0
# 172  511090873.0  2014.0
# 432       4975.0  2013.0
# 685       5500.0  2012.0
#
# [125 rows x 12 columns]

# %%
df_final.drop(indices_arr, axis=0, inplace=True)
df_final.shape
# Out:
# (1785, 12)

# %%
df_num_final = df_final.select_dtypes(exclude="object")
# Dropping year and Temp attribute because they are not used for computing WQI
df_num_final.drop(["year", "Temp"], axis=1, inplace=True)

# Weight Vector(wi)
wi = np.array([0.2213, 0.2604, 0.0022, 0.4426, 0.0492, 0.0221, 0.0022])

# Standard values of parameters(si)
si = np.array([10, 8.5, 1000, 5, 45, 100, 1000])

# Ideal values of paramters(vIdeal)
vIdeal = np.array([14.6, 7, 0, 0, 0, 0, 0])

def calc_wqi(sample):
    wqi_sample = 0
    num_col = 7
    for index in range(num_col):
        v_index = sample[index] # Obeserved value of sample at index
        v_index_ideal = vIdeal[index] # Ideal value of obeserved value
        w_index = wi[index] # weight of corresponding parameter of obeserved value
        std_index = si[index] # Standard value recommended for obeserved value
        q_index = (v_index - v_index_ideal) / (std_index - v_index_ideal)
        q_index = q_index * 100 # Final qi value of obeserved value
        wqi_sample += q_index*w_index
    return wqi_sample

# %%
def calc_wqi_for_df(df):
    wqi_arr = []
    for index in range(df.shape[0]):
        index_row = df.iloc[index, :]
        wqi_row = calc_wqi(index_row)
        wqi_arr.append(wqi_row)
    return wqi_arr

# %%
wqi_arr = calc_wqi_for_df(df_num_final)
# Converting oridnary array to numpy array
wqi_arr = np.array(wqi_arr)
wqi_arr = np.reshape(wqi_arr, (-1, 1))

# Resetting index values of the dataframes
wqi_arr_df = pd.DataFrame(wqi_arr, columns=["WQI"]).reset_index()
df_final = df_final.reset_index()

# %%
df_wqi = pd.concat([df_final, pd.DataFrame(wqi_arr, columns=["WQI"])], axis=1)
df_wqi.drop("index", axis=1, inplace=True)
df_wqi.shape
# Out:
# (1785, 13)

# %%
df_wqi[(df_wqi["WQI"] < 0)]
# Out:
#     STATION CODE                                      LOCATIONS        STATE  \
# 196         3375  LUKHA RIVER AT MYNDIHATI (TRIBUTARY OF LUNAR)    MEGHALAYA
# 231            2           DAMANGANGA AT D/S OF MADHUBAN, DAMAN  DAMAN & DIU
# 234         1865                        RIVER DHADAR AT KOTHADA      GUJARAT
# 446         3375                                    LUKHA RIVER    MEGHALAYA
# 719         3375  LUKHA RIVER AT MYNDIHATI (TRIBUTARY OF LUNAR)    MEGHALAYA
#
#      Temp   DO   PH  Conductivity     BOD    NI  Fec_col  Tot_col    year  \
# 196  20.5  6.7  2.7        1350.0  3.3000  1.10      7.0     16.0  2014.0
# 231  27.0  6.7  0.0         208.0  1.8965  0.52    233.0    465.0  2013.0
# 234  27.0  6.7  0.0         506.0  1.8965  6.00     26.0    227.0  2013.0
# 446  21.3  6.8  2.7        1074.0  3.2000  2.33      4.0     11.0  2013.0
# 719  25.0  6.9  2.6        1072.0  3.2000  1.17      3.0     21.0  2012.0
#
#            WQI
# 196  -6.855044
# 231 -61.372099
# 234 -65.334452
# 446  -8.214971
# 719 -10.579224

# %%
df_neg_indices = df_wqi[(df_wqi["WQI"] < 0)].index
df_wqi.drop(df_neg_indices, axis=0, inplace=True)

# %%
df_wqi["WQI clf"] = df_wqi["WQI"].apply(lambda x: (3 if (x <= 25)  
                                        else(2 if (26<=x<=50) 
                                        else(1 if (51<=x<=75) 
                                        else 0))))

# %%
df_wqi.tail()
# Out:
#      STATION CODE                                          LOCATIONS  \
# 1780         1329  TAMBIRAPARANI AT RAIL BDG. NR. AMBASAMUDAM, TA...
# 1781         1330            TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU
# 1782         1450  PALAR AT VANIYAMBADI WATER SUPPLY HEAD WORK, T...
# 1783         1403                 GUMTI AT U/S SOUTH TRIPURA,TRIPURA
# 1784         1404                GUMTI AT D/S SOUTH TRIPURA, TRIPURA
#
#           STATE  Temp   DO    PH  Conductivity    BOD     NI  Fec_col  \
# 1780  TAMILNADU  27.0  7.4  7.00          88.5  0.977  0.186     27.0
# 1781  TAMILNADU  27.0  6.6  7.81         603.2  2.675  0.263     40.0
# 1782  TAMILNADU  28.0  6.6  7.49         571.5  2.091  0.256    151.0
# 1783    TRIPURA  28.0  5.4  7.16          75.8  2.092  0.520    404.0
# 1784    TRIPURA  30.0  5.4  7.37         104.8  1.802  0.215    456.0
#
#       Tot_col    year        WQI  WQI clf
# 1780    105.0  2005.0  43.946271        2
# 1781    191.0  2005.0  77.315135        0
# 1782    273.0  2005.0  69.053768        1
# 1783    513.0  2005.0  74.670773        1
# 1784    557.0  2005.0  76.881207        0

# %%
df_wqi.describe()
# Out:
#               Temp           DO           PH  Conductivity          BOD  \
# count  1780.000000  1780.000000  1780.000000   1780.000000  1780.000000
# mean     26.241931     6.432263     7.228045   1006.325691     3.961788
# std       3.231044     1.258875     0.582761   2764.600752     7.130494
# min      10.000000     0.000000     2.900000     11.000000     0.100000
# 25%      25.000000     6.000000     6.900000     83.000000     1.100000
# 50%      27.000000     6.700000     7.224500    183.000000     1.800000
# 75%      28.200000     7.200000     7.600000    489.250000     3.400000
# max      35.000000    10.000000     9.010000  18569.000000    88.000000
#
#                 NI        Fec_col        Tot_col         year          WQI  \
# count  1780.000000    1780.000000    1780.000000  1780.000000  1780.000000
# mean      1.119716    2264.420646    7242.598876  2010.380337   130.303409
# std       1.629483    8259.474360   40230.193629     2.704223   222.261326
# min       0.000000       0.000000       0.000000  2005.000000    16.795814
# 25%       0.263000      46.000000     108.750000  2008.000000    54.641036
# 50%       0.520000     233.000000     465.000000  2011.000000    69.840286
# 75%       1.100000     672.500000    1650.000000  2013.000000    94.348696
# max      13.200000  150250.000000  967500.000000  2014.000000  3524.421534
#
#            WQI clf
# count  1780.000000
# mean      0.715169
# std       0.731754
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       3.000000

# %%
features = list(df_wqi.columns)[:11]
data_f = df_wqi[features]
data_f.describe()
# Out:
#               Temp           DO           PH  Conductivity          BOD  \
# count  1780.000000  1780.000000  1780.000000   1780.000000  1780.000000
# mean     26.241931     6.432263     7.228045   1006.325691     3.961788
# std       3.231044     1.258875     0.582761   2764.600752     7.130494
# min      10.000000     0.000000     2.900000     11.000000     0.100000
# 25%      25.000000     6.000000     6.900000     83.000000     1.100000
# 50%      27.000000     6.700000     7.224500    183.000000     1.800000
# 75%      28.200000     7.200000     7.600000    489.250000     3.400000
# max      35.000000    10.000000     9.010000  18569.000000    88.000000
#
#                 NI        Fec_col        Tot_col
# count  1780.000000    1780.000000    1780.000000
# mean      1.119716    2264.420646    7242.598876
# std       1.629483    8259.474360   40230.193629
# min       0.000000       0.000000       0.000000
# 25%       0.263000      46.000000     108.750000
# 50%       0.520000     233.000000     465.000000
# 75%       1.100000     672.500000    1650.000000
# max      13.200000  150250.000000  967500.000000

# %%
features = list(df_wqi.columns)[:]
data_cluster = df_wqi['WQI clf']
data_cluster.describe()
# Out:
# count    1780.000000
# mean        0.715169
# std         0.731754
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         3.000000
# Name: WQI clf, dtype: float64

# %%
data_f
# Out:
#      STATION CODE                                          LOCATIONS  \
# 0            1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN
# 1            1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...
# 2            1475                                ZUARI AT PANCHAWADI
# 3            3181                        RIVER ZUARI AT BORIM BRIDGE
# 4            3182                       RIVER ZUARI AT MARCAIM JETTY
# ...           ...                                                ...
# 1780         1329  TAMBIRAPARANI AT RAIL BDG. NR. AMBASAMUDAM, TA...
# 1781         1330            TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU
# 1782         1450  PALAR AT VANIYAMBADI WATER SUPPLY HEAD WORK, T...
# 1783         1403                 GUMTI AT U/S SOUTH TRIPURA,TRIPURA
# 1784         1404                GUMTI AT D/S SOUTH TRIPURA, TRIPURA
#
#             STATE  Temp   DO    PH  Conductivity     BOD     NI  Fec_col  \
# 0     DAMAN & DIU  30.6  6.7  7.50         203.0  1.8965  0.100     11.0
# 1             GOA  29.8  5.7  7.20         189.0  2.0000  0.200   4953.0
# 2             GOA  29.5  6.3  6.90         179.0  1.7000  0.100   3243.0
# 3             GOA  29.7  5.8  6.90          64.0  3.8000  0.500   5382.0
# 4             GOA  29.5  5.8  7.30          83.0  1.9000  0.400   3428.0
# ...           ...   ...  ...   ...           ...     ...    ...      ...
# 1780    TAMILNADU  27.0  7.4  7.00          88.5  0.9770  0.186     27.0
# 1781    TAMILNADU  27.0  6.6  7.81         603.2  2.6750  0.263     40.0
# 1782    TAMILNADU  28.0  6.6  7.49         571.5  2.0910  0.256    151.0
# 1783      TRIPURA  28.0  5.4  7.16          75.8  2.0920  0.520    404.0
# 1784      TRIPURA  30.0  5.4  7.37         104.8  1.8020  0.215    456.0
#
#       Tot_col
# 0        27.0
# 1      8391.0
# 2      5330.0
# 3      8443.0
# 4      5500.0
# ...       ...
# 1780    105.0
# 1781    191.0
# 1782    273.0
# 1783    513.0
# 1784    557.0
#
# [1780 rows x 11 columns]

# %%
data_f
# Out:
#      STATION CODE                                          LOCATIONS  \
# 0            1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN
# 1            1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...
# 2            1475                                ZUARI AT PANCHAWADI
# 3            3181                        RIVER ZUARI AT BORIM BRIDGE
# 4            3182                       RIVER ZUARI AT MARCAIM JETTY
# ...           ...                                                ...
# 1780         1329  TAMBIRAPARANI AT RAIL BDG. NR. AMBASAMUDAM, TA...
# 1781         1330            TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU
# 1782         1450  PALAR AT VANIYAMBADI WATER SUPPLY HEAD WORK, T...
# 1783         1403                 GUMTI AT U/S SOUTH TRIPURA,TRIPURA
# 1784         1404                GUMTI AT D/S SOUTH TRIPURA, TRIPURA
#
#             STATE  Temp   DO    PH  Conductivity     BOD     NI  Fec_col  \
# 0     DAMAN & DIU  30.6  6.7  7.50         203.0  1.8965  0.100     11.0
# 1             GOA  29.8  5.7  7.20         189.0  2.0000  0.200   4953.0
# 2             GOA  29.5  6.3  6.90         179.0  1.7000  0.100   3243.0
# 3             GOA  29.7  5.8  6.90          64.0  3.8000  0.500   5382.0
# 4             GOA  29.5  5.8  7.30          83.0  1.9000  0.400   3428.0
# ...           ...   ...  ...   ...           ...     ...    ...      ...
# 1780    TAMILNADU  27.0  7.4  7.00          88.5  0.9770  0.186     27.0
# 1781    TAMILNADU  27.0  6.6  7.81         603.2  2.6750  0.263     40.0
# 1782    TAMILNADU  28.0  6.6  7.49         571.5  2.0910  0.256    151.0
# 1783      TRIPURA  28.0  5.4  7.16          75.8  2.0920  0.520    404.0
# 1784      TRIPURA  30.0  5.4  7.37         104.8  1.8020  0.215    456.0
#
#       Tot_col
# 0        27.0
# 1      8391.0
# 2      5330.0
# 3      8443.0
# 4      5500.0
# ...       ...
# 1780    105.0
# 1781    191.0
# 1782    273.0
# 1783    513.0
# 1784    557.0
#
# [1780 rows x 11 columns]

# %%
Y = data_cluster

# %%
df_wqi
# Out:
#      STATION CODE                                          LOCATIONS  \
# 0            1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN
# 1            1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...
# 2            1475                                ZUARI AT PANCHAWADI
# 3            3181                        RIVER ZUARI AT BORIM BRIDGE
# 4            3182                       RIVER ZUARI AT MARCAIM JETTY
# ...           ...                                                ...
# 1780         1329  TAMBIRAPARANI AT RAIL BDG. NR. AMBASAMUDAM, TA...
# 1781         1330            TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU
# 1782         1450  PALAR AT VANIYAMBADI WATER SUPPLY HEAD WORK, T...
# 1783         1403                 GUMTI AT U/S SOUTH TRIPURA,TRIPURA
# 1784         1404                GUMTI AT D/S SOUTH TRIPURA, TRIPURA
#
#             STATE  Temp   DO    PH  Conductivity     BOD     NI  Fec_col  \
# 0     DAMAN & DIU  30.6  6.7  7.50         203.0  1.8965  0.100     11.0
# 1             GOA  29.8  5.7  7.20         189.0  2.0000  0.200   4953.0
# 2             GOA  29.5  6.3  6.90         179.0  1.7000  0.100   3243.0
# 3             GOA  29.7  5.8  6.90          64.0  3.8000  0.500   5382.0
# 4             GOA  29.5  5.8  7.30          83.0  1.9000  0.400   3428.0
# ...           ...   ...  ...   ...           ...     ...    ...      ...
# 1780    TAMILNADU  27.0  7.4  7.00          88.5  0.9770  0.186     27.0
# 1781    TAMILNADU  27.0  6.6  7.81         603.2  2.6750  0.263     40.0
# 1782    TAMILNADU  28.0  6.6  7.49         571.5  2.0910  0.256    151.0
# 1783      TRIPURA  28.0  5.4  7.16          75.8  2.0920  0.520    404.0
# 1784      TRIPURA  30.0  5.4  7.37         104.8  1.8020  0.215    456.0
#
#       Tot_col    year         WQI  WQI clf
# 0        27.0  2014.0   63.778321        1
# 1      8391.0  2014.0  175.363506        0
# 2      5330.0  2014.0  126.135831        0
# 3      8443.0  2014.0  195.105659        0
# 4      5500.0  2014.0  141.393246        0
# ...       ...     ...         ...      ...
# 1780    105.0  2005.0   43.946271        2
# 1781    191.0  2005.0   77.315135        0
# 1782    273.0  2005.0   69.053768        1
# 1783    513.0  2005.0   74.670773        1
# 1784    557.0  2005.0   76.881207        0
#
# [1780 rows x 14 columns]

# %%
features = list(df_wqi.columns)[4:11]
X = df_wqi[features]
X.describe()
X.dtypes
# Out:
# DO              float64
# PH              float64
# Conductivity    float64
# BOD             float64
# NI              float64
# Fec_col         float64
# Tot_col         float64
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[ 0.21273941,  0.46679752, -0.29065732, ..., -0.62596683,
#         -0.27290525, -0.1794082 ],
#        [-0.58184389, -0.04813777, -0.29572276, ..., -0.56458042,
#          0.32560606,  0.02855377],
#        [-0.10509391, -0.56307306, -0.29934094, ..., -0.62596683,
#          0.11851291, -0.04755474],
#        ...,
#        [ 0.13328108,  0.44963301, -0.15732756, ..., -0.53020403,
#         -0.25595025, -0.17329167],
#        [-0.82021888, -0.11679581, -0.33668051, ..., -0.36814393,
#         -0.22531016, -0.16732433],
#        [-0.82021888,  0.24365889, -0.3261878 , ..., -0.55537246,
#         -0.21901259, -0.16623031]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, Y, test_size=0.5, random_state=30)

# %%
import catboost as cb
classifier = cb.CatBoostClassifier()
y_score=classifier.fit(X_train, y_train).predict_proba(X_test)
# Out:
# Learning rate set to 0.078658
# 0:	learn: 1.2864842	total: 156ms	remaining: 2m 36s
# 1:	learn: 1.1941452	total: 166ms	remaining: 1m 22s
# 2:	learn: 1.1335254	total: 175ms	remaining: 58.2s
# 3:	learn: 1.0640470	total: 185ms	remaining: 46.1s
# 4:	learn: 1.0037737	total: 196ms	remaining: 38.9s
# 5:	learn: 0.9465123	total: 205ms	remaining: 33.9s
# 6:	learn: 0.9012572	total: 215ms	remaining: 30.5s
# 7:	learn: 0.8565900	total: 225ms	remaining: 27.9s
# 8:	learn: 0.8203291	total: 234ms	remaining: 25.8s
# 9:	learn: 0.7822829	total: 244ms	remaining: 24.1s
# 10:	learn: 0.7509934	total: 253ms	remaining: 22.8s
# 11:	learn: 0.7247791	total: 263ms	remaining: 21.6s
# 12:	learn: 0.6972710	total: 271ms	remaining: 20.6s
# 13:	learn: 0.6734209	total: 281ms	remaining: 19.8s
# 14:	learn: 0.6486936	total: 290ms	remaining: 19.1s
# 15:	learn: 0.6269159	total: 300ms	remaining: 18.4s
# 16:	learn: 0.6052331	total: 309ms	remaining: 17.9s
# 17:	learn: 0.5898975	total: 318ms	remaining: 17.4s
# 18:	learn: 0.5722336	total: 327ms	remaining: 16.9s
# 19:	learn: 0.5581646	total: 337ms	remaining: 16.5s
# 20:	learn: 0.5439561	total: 346ms	remaining: 16.1s
# 21:	learn: 0.5281207	total: 356ms	remaining: 15.8s
# 22:	learn: 0.5162507	total: 364ms	remaining: 15.5s
# 23:	learn: 0.5019210	total: 374ms	remaining: 15.2s
# 24:	learn: 0.4891459	total: 383ms	remaining: 14.9s
# 25:	learn: 0.4796949	total: 392ms	remaining: 14.7s
# 26:	learn: 0.4706096	total: 402ms	remaining: 14.5s
# 27:	learn: 0.4610004	total: 411ms	remaining: 14.3s
# 28:	learn: 0.4509962	total: 421ms	remaining: 14.1s
# 29:	learn: 0.4415360	total: 429ms	remaining: 13.9s
# 30:	learn: 0.4329855	total: 439ms	remaining: 13.7s
# 31:	learn: 0.4252870	total: 448ms	remaining: 13.6s
# 32:	learn: 0.4180143	total: 457ms	remaining: 13.4s
# 33:	learn: 0.4110581	total: 467ms	remaining: 13.3s
# 34:	learn: 0.4038111	total: 476ms	remaining: 13.1s
# 35:	learn: 0.3965165	total: 486ms	remaining: 13s
# 36:	learn: 0.3899585	total: 495ms	remaining: 12.9s
# 37:	learn: 0.3824596	total: 504ms	remaining: 12.8s
# 38:	learn: 0.3764674	total: 513ms	remaining: 12.6s
# 39:	learn: 0.3707049	total: 522ms	remaining: 12.5s
# 40:	learn: 0.3656185	total: 530ms	remaining: 12.4s
# 41:	learn: 0.3593406	total: 539ms	remaining: 12.3s
# 42:	learn: 0.3551520	total: 548ms	remaining: 12.2s
# 43:	learn: 0.3504453	total: 557ms	remaining: 12.1s
# 44:	learn: 0.3459245	total: 567ms	remaining: 12s
# 45:	learn: 0.3429145	total: 575ms	remaining: 11.9s
# 46:	learn: 0.3395689	total: 585ms	remaining: 11.9s
# 47:	learn: 0.3360070	total: 593ms	remaining: 11.8s
# 48:	learn: 0.3324409	total: 603ms	remaining: 11.7s
# 49:	learn: 0.3300633	total: 612ms	remaining: 11.6s
# 50:	learn: 0.3254151	total: 621ms	remaining: 11.5s
# 51:	learn: 0.3212782	total: 630ms	remaining: 11.5s
# 52:	learn: 0.3174577	total: 639ms	remaining: 11.4s
# 53:	learn: 0.3143547	total: 649ms	remaining: 11.4s
# 54:	learn: 0.3104116	total: 657ms	remaining: 11.3s
# 55:	learn: 0.3076639	total: 665ms	remaining: 11.2s
# 56:	learn: 0.3044051	total: 672ms	remaining: 11.1s
# 57:	learn: 0.3016420	total: 682ms	remaining: 11.1s
# 58:	learn: 0.2991600	total: 690ms	remaining: 11s
# 59:	learn: 0.2961087	total: 699ms	remaining: 11s
# 60:	learn: 0.2936201	total: 707ms	remaining: 10.9s
# 61:	learn: 0.2900851	total: 716ms	remaining: 10.8s
# 62:	learn: 0.2875490	total: 725ms	remaining: 10.8s
# 63:	learn: 0.2848010	total: 734ms	remaining: 10.7s
# 64:	learn: 0.2820931	total: 743ms	remaining: 10.7s
# 65:	learn: 0.2794321	total: 752ms	remaining: 10.6s
# 66:	learn: 0.2763524	total: 762ms	remaining: 10.6s
# 67:	learn: 0.2742256	total: 771ms	remaining: 10.6s
# 68:	learn: 0.2714895	total: 781ms	remaining: 10.5s
# 69:	learn: 0.2690315	total: 791ms	remaining: 10.5s
# 70:	learn: 0.2672869	total: 800ms	remaining: 10.5s
# 71:	learn: 0.2657842	total: 808ms	remaining: 10.4s
# 72:	learn: 0.2629978	total: 818ms	remaining: 10.4s
# 73:	learn: 0.2604764	total: 828ms	remaining: 10.4s
# 74:	learn: 0.2581392	total: 838ms	remaining: 10.3s
# 75:	learn: 0.2559100	total: 848ms	remaining: 10.3s
# 76:	learn: 0.2538423	total: 857ms	remaining: 10.3s
# 77:	learn: 0.2528429	total: 866ms	remaining: 10.2s
# 78:	learn: 0.2501867	total: 875ms	remaining: 10.2s
# 79:	learn: 0.2483185	total: 884ms	remaining: 10.2s
# 80:	learn: 0.2468867	total: 893ms	remaining: 10.1s
# 81:	learn: 0.2451725	total: 902ms	remaining: 10.1s
# 82:	learn: 0.2441450	total: 912ms	remaining: 10.1s
# 83:	learn: 0.2431923	total: 921ms	remaining: 10s
# 84:	learn: 0.2419805	total: 931ms	remaining: 10s
# 85:	learn: 0.2402014	total: 940ms	remaining: 9.99s
# 86:	learn: 0.2388813	total: 950ms	remaining: 9.97s
# 87:	learn: 0.2369565	total: 959ms	remaining: 9.94s
# 88:	learn: 0.2352560	total: 968ms	remaining: 9.91s
# 89:	learn: 0.2334321	total: 978ms	remaining: 9.89s
# 90:	learn: 0.2322047	total: 987ms	remaining: 9.86s
# 91:	learn: 0.2304033	total: 995ms	remaining: 9.82s
# 92:	learn: 0.2290769	total: 1s	remaining: 9.8s
# 93:	learn: 0.2276169	total: 1.01s	remaining: 9.78s
# 94:	learn: 0.2263781	total: 1.02s	remaining: 9.75s
# 95:	learn: 0.2247129	total: 1.03s	remaining: 9.72s
# 96:	learn: 0.2232972	total: 1.04s	remaining: 9.69s
# 97:	learn: 0.2221087	total: 1.05s	remaining: 9.68s
# 98:	learn: 0.2202393	total: 1.06s	remaining: 9.65s
# 99:	learn: 0.2184181	total: 1.07s	remaining: 9.63s
# 100:	learn: 0.2174083	total: 1.08s	remaining: 9.61s
# 101:	learn: 0.2159656	total: 1.09s	remaining: 9.58s
# 102:	learn: 0.2149974	total: 1.1s	remaining: 9.56s
# 103:	learn: 0.2133749	total: 1.11s	remaining: 9.53s
# 104:	learn: 0.2126323	total: 1.12s	remaining: 9.51s
# 105:	learn: 0.2115373	total: 1.13s	remaining: 9.49s
# 106:	learn: 0.2100475	total: 1.13s	remaining: 9.46s
# 107:	learn: 0.2083813	total: 1.14s	remaining: 9.44s
# 108:	learn: 0.2069142	total: 1.15s	remaining: 9.42s
# 109:	learn: 0.2062624	total: 1.16s	remaining: 9.4s
# 110:	learn: 0.2050520	total: 1.17s	remaining: 9.37s
# 111:	learn: 0.2037474	total: 1.18s	remaining: 9.36s
# 112:	learn: 0.2024778	total: 1.19s	remaining: 9.34s
# 113:	learn: 0.2015978	total: 1.2s	remaining: 9.31s
# 114:	learn: 0.2004263	total: 1.21s	remaining: 9.3s
# 115:	learn: 0.1997392	total: 1.22s	remaining: 9.28s
# 116:	learn: 0.1980336	total: 1.23s	remaining: 9.25s
# 117:	learn: 0.1974694	total: 1.23s	remaining: 9.23s
# 118:	learn: 0.1967208	total: 1.24s	remaining: 9.21s
# 119:	learn: 0.1956969	total: 1.25s	remaining: 9.19s
# 120:	learn: 0.1947060	total: 1.26s	remaining: 9.18s
# 121:	learn: 0.1936780	total: 1.27s	remaining: 9.16s
# 122:	learn: 0.1921357	total: 1.28s	remaining: 9.14s
# 123:	learn: 0.1909243	total: 1.29s	remaining: 9.13s
# 124:	learn: 0.1900890	total: 1.3s	remaining: 9.11s
# 125:	learn: 0.1891189	total: 1.31s	remaining: 9.08s
# 126:	learn: 0.1876593	total: 1.32s	remaining: 9.07s
# 127:	learn: 0.1866040	total: 1.33s	remaining: 9.05s
# 128:	learn: 0.1855968	total: 1.34s	remaining: 9.03s
# 129:	learn: 0.1849083	total: 1.35s	remaining: 9.01s
# 130:	learn: 0.1838752	total: 1.35s	remaining: 8.99s
# 131:	learn: 0.1830022	total: 1.36s	remaining: 8.97s
# 132:	learn: 0.1817078	total: 1.37s	remaining: 8.95s
# 133:	learn: 0.1806431	total: 1.38s	remaining: 8.93s
# 134:	learn: 0.1798962	total: 1.39s	remaining: 8.92s
# 135:	learn: 0.1787757	total: 1.4s	remaining: 8.9s
# 136:	learn: 0.1782651	total: 1.41s	remaining: 8.88s
# 137:	learn: 0.1775690	total: 1.42s	remaining: 8.87s
# 138:	learn: 0.1771324	total: 1.43s	remaining: 8.85s
# 139:	learn: 0.1762445	total: 1.44s	remaining: 8.84s
# 140:	learn: 0.1754245	total: 1.45s	remaining: 8.82s
# 141:	learn: 0.1749831	total: 1.46s	remaining: 8.81s
# 142:	learn: 0.1742772	total: 1.47s	remaining: 8.79s
# 143:	learn: 0.1736795	total: 1.48s	remaining: 8.78s
# 144:	learn: 0.1730735	total: 1.49s	remaining: 8.76s
# 145:	learn: 0.1722107	total: 1.49s	remaining: 8.74s
# 146:	learn: 0.1718111	total: 1.5s	remaining: 8.72s
# 147:	learn: 0.1706019	total: 1.51s	remaining: 8.71s
# 148:	learn: 0.1702355	total: 1.52s	remaining: 8.7s
# 149:	learn: 0.1699386	total: 1.53s	remaining: 8.68s
# 150:	learn: 0.1695622	total: 1.54s	remaining: 8.66s
# 151:	learn: 0.1691104	total: 1.55s	remaining: 8.65s
# 152:	learn: 0.1686002	total: 1.56s	remaining: 8.64s
# 153:	learn: 0.1678534	total: 1.57s	remaining: 8.62s
# 154:	learn: 0.1674646	total: 1.58s	remaining: 8.61s
# 155:	learn: 0.1661285	total: 1.59s	remaining: 8.6s
# 156:	learn: 0.1656118	total: 1.6s	remaining: 8.58s
# 157:	learn: 0.1648160	total: 1.61s	remaining: 8.56s
# 158:	learn: 0.1640747	total: 1.62s	remaining: 8.55s
# 159:	learn: 0.1633498	total: 1.63s	remaining: 8.53s
# 160:	learn: 0.1628346	total: 1.63s	remaining: 8.52s
# 161:	learn: 0.1623231	total: 1.64s	remaining: 8.5s
# 162:	learn: 0.1617653	total: 1.65s	remaining: 8.48s
# 163:	learn: 0.1611043	total: 1.66s	remaining: 8.47s
# 164:	learn: 0.1602596	total: 1.67s	remaining: 8.46s
# 165:	learn: 0.1594968	total: 1.68s	remaining: 8.44s
# 166:	learn: 0.1589765	total: 1.69s	remaining: 8.43s
# 167:	learn: 0.1585329	total: 1.7s	remaining: 8.41s
# 168:	learn: 0.1573611	total: 1.71s	remaining: 8.4s
# 169:	learn: 0.1565659	total: 1.72s	remaining: 8.38s
# 170:	learn: 0.1560892	total: 1.73s	remaining: 8.37s
# 171:	learn: 0.1553818	total: 1.74s	remaining: 8.36s
# 172:	learn: 0.1547239	total: 1.75s	remaining: 8.34s
# 173:	learn: 0.1542172	total: 1.75s	remaining: 8.33s
# 174:	learn: 0.1536613	total: 1.76s	remaining: 8.31s
# 175:	learn: 0.1531651	total: 1.77s	remaining: 8.3s
# 176:	learn: 0.1525647	total: 1.78s	remaining: 8.29s
# 177:	learn: 0.1518299	total: 1.79s	remaining: 8.28s
# 178:	learn: 0.1510346	total: 1.8s	remaining: 8.26s
# 179:	learn: 0.1506926	total: 1.81s	remaining: 8.24s
# 180:	learn: 0.1500629	total: 1.82s	remaining: 8.23s
# 181:	learn: 0.1494958	total: 1.83s	remaining: 8.22s
# 182:	learn: 0.1488436	total: 1.84s	remaining: 8.2s
# 183:	learn: 0.1483778	total: 1.85s	remaining: 8.19s
# 184:	learn: 0.1471302	total: 1.85s	remaining: 8.17s
# 185:	learn: 0.1466417	total: 1.86s	remaining: 8.15s
# 186:	learn: 0.1458840	total: 1.87s	remaining: 8.14s
# 187:	learn: 0.1450500	total: 1.88s	remaining: 8.13s
# 188:	learn: 0.1444153	total: 1.89s	remaining: 8.11s
# 189:	learn: 0.1437738	total: 1.9s	remaining: 8.1s
# 190:	learn: 0.1432750	total: 1.91s	remaining: 8.09s
# 191:	learn: 0.1429192	total: 1.92s	remaining: 8.08s
# 192:	learn: 0.1424927	total: 1.93s	remaining: 8.06s
# 193:	learn: 0.1418187	total: 1.94s	remaining: 8.05s
# 194:	learn: 0.1413138	total: 1.95s	remaining: 8.04s
# 195:	learn: 0.1406504	total: 1.96s	remaining: 8.03s
# 196:	learn: 0.1402433	total: 1.97s	remaining: 8.02s
# 197:	learn: 0.1396011	total: 1.98s	remaining: 8s
# 198:	learn: 0.1392092	total: 1.98s	remaining: 7.99s
# 199:	learn: 0.1385850	total: 1.99s	remaining: 7.98s
# 200:	learn: 0.1383083	total: 2s	remaining: 7.96s
# 201:	learn: 0.1377684	total: 2.01s	remaining: 7.95s
# 202:	learn: 0.1370030	total: 2.02s	remaining: 7.92s
# 203:	learn: 0.1362461	total: 2.03s	remaining: 7.92s
# 204:	learn: 0.1356643	total: 2.04s	remaining: 7.9s
# 205:	learn: 0.1351436	total: 2.05s	remaining: 7.89s
# 206:	learn: 0.1348859	total: 2.06s	remaining: 7.88s
# 207:	learn: 0.1342222	total: 2.06s	remaining: 7.86s
# 208:	learn: 0.1337831	total: 2.07s	remaining: 7.85s
# 209:	learn: 0.1330352	total: 2.08s	remaining: 7.83s
# 210:	learn: 0.1326307	total: 2.09s	remaining: 7.82s
# 211:	learn: 0.1318399	total: 2.1s	remaining: 7.8s
# 212:	learn: 0.1316297	total: 2.11s	remaining: 7.79s
# 213:	learn: 0.1313241	total: 2.12s	remaining: 7.78s
# 214:	learn: 0.1310983	total: 2.13s	remaining: 7.76s
# 215:	learn: 0.1305628	total: 2.13s	remaining: 7.75s
# 216:	learn: 0.1301442	total: 2.14s	remaining: 7.74s
# 217:	learn: 0.1298570	total: 2.15s	remaining: 7.73s
# 218:	learn: 0.1294436	total: 2.16s	remaining: 7.71s
# 219:	learn: 0.1288252	total: 2.17s	remaining: 7.7s
# 220:	learn: 0.1286362	total: 2.18s	remaining: 7.69s
# 221:	learn: 0.1280442	total: 2.19s	remaining: 7.68s
# 222:	learn: 0.1273989	total: 2.2s	remaining: 7.67s
# 223:	learn: 0.1270506	total: 2.21s	remaining: 7.66s
# 224:	learn: 0.1265087	total: 2.22s	remaining: 7.64s
# 225:	learn: 0.1262246	total: 2.23s	remaining: 7.63s
# 226:	learn: 0.1255397	total: 2.24s	remaining: 7.61s
# 227:	learn: 0.1246589	total: 2.25s	remaining: 7.6s
# 228:	learn: 0.1243213	total: 2.25s	remaining: 7.59s
# 229:	learn: 0.1239826	total: 2.27s	remaining: 7.58s
# 230:	learn: 0.1235819	total: 2.27s	remaining: 7.57s
# 231:	learn: 0.1230184	total: 2.28s	remaining: 7.56s
# 232:	learn: 0.1227278	total: 2.29s	remaining: 7.55s
# 233:	learn: 0.1225915	total: 2.3s	remaining: 7.54s
# 234:	learn: 0.1220732	total: 2.31s	remaining: 7.53s
# 235:	learn: 0.1217457	total: 2.32s	remaining: 7.51s
# 236:	learn: 0.1215705	total: 2.33s	remaining: 7.5s
# 237:	learn: 0.1212313	total: 2.34s	remaining: 7.49s
# 238:	learn: 0.1209910	total: 2.35s	remaining: 7.48s
# 239:	learn: 0.1205605	total: 2.36s	remaining: 7.47s
# 240:	learn: 0.1204159	total: 2.37s	remaining: 7.46s
# 241:	learn: 0.1199366	total: 2.38s	remaining: 7.45s
# 242:	learn: 0.1196572	total: 2.39s	remaining: 7.43s
# 243:	learn: 0.1195249	total: 2.39s	remaining: 7.4s
# 244:	learn: 0.1190700	total: 2.4s	remaining: 7.4s
# 245:	learn: 0.1189178	total: 2.41s	remaining: 7.38s
# 246:	learn: 0.1183224	total: 2.42s	remaining: 7.37s
# 247:	learn: 0.1179215	total: 2.43s	remaining: 7.36s
# 248:	learn: 0.1175125	total: 2.44s	remaining: 7.35s
# 249:	learn: 0.1169921	total: 2.45s	remaining: 7.34s
# 250:	learn: 0.1166690	total: 2.46s	remaining: 7.33s
# 251:	learn: 0.1161939	total: 2.46s	remaining: 7.31s
# 252:	learn: 0.1157852	total: 2.47s	remaining: 7.3s
# 253:	learn: 0.1155570	total: 2.48s	remaining: 7.29s
# 254:	learn: 0.1152566	total: 2.49s	remaining: 7.27s
# 255:	learn: 0.1148710	total: 2.5s	remaining: 7.26s
# 256:	learn: 0.1145450	total: 2.51s	remaining: 7.25s
# 257:	learn: 0.1142129	total: 2.52s	remaining: 7.24s
# 258:	learn: 0.1139218	total: 2.53s	remaining: 7.23s
# 259:	learn: 0.1135488	total: 2.54s	remaining: 7.22s
# 260:	learn: 0.1131014	total: 2.54s	remaining: 7.21s
# 261:	learn: 0.1127448	total: 2.55s	remaining: 7.2s
# 262:	learn: 0.1124233	total: 2.56s	remaining: 7.17s
# 263:	learn: 0.1122082	total: 2.57s	remaining: 7.16s
# 264:	learn: 0.1119876	total: 2.58s	remaining: 7.15s
# 265:	learn: 0.1114397	total: 2.59s	remaining: 7.14s
# 266:	learn: 0.1110649	total: 2.6s	remaining: 7.13s
# 267:	learn: 0.1109121	total: 2.61s	remaining: 7.12s
# 268:	learn: 0.1103641	total: 2.61s	remaining: 7.11s
# 269:	learn: 0.1101920	total: 2.62s	remaining: 7.1s
# 270:	learn: 0.1099164	total: 2.63s	remaining: 7.09s
# 271:	learn: 0.1097238	total: 2.64s	remaining: 7.07s
# 272:	learn: 0.1096441	total: 2.65s	remaining: 7.05s
# 273:	learn: 0.1094856	total: 2.65s	remaining: 7.04s
# 274:	learn: 0.1091920	total: 2.66s	remaining: 7.03s
# 275:	learn: 0.1087790	total: 2.67s	remaining: 7.01s
# 276:	learn: 0.1085543	total: 2.68s	remaining: 7s
# 277:	learn: 0.1080755	total: 2.69s	remaining: 6.99s
# 278:	learn: 0.1079089	total: 2.7s	remaining: 6.98s
# 279:	learn: 0.1077611	total: 2.71s	remaining: 6.97s
# 280:	learn: 0.1075906	total: 2.72s	remaining: 6.96s
# 281:	learn: 0.1071626	total: 2.73s	remaining: 6.95s
# 282:	learn: 0.1067727	total: 2.74s	remaining: 6.94s
# 283:	learn: 0.1065735	total: 2.75s	remaining: 6.93s
# 284:	learn: 0.1062739	total: 2.76s	remaining: 6.92s
# 285:	learn: 0.1061904	total: 2.77s	remaining: 6.91s
# 286:	learn: 0.1057362	total: 2.77s	remaining: 6.89s
# 287:	learn: 0.1053622	total: 2.78s	remaining: 6.88s
# 288:	learn: 0.1051202	total: 2.79s	remaining: 6.87s
# 289:	learn: 0.1049411	total: 2.8s	remaining: 6.86s
# 290:	learn: 0.1046930	total: 2.81s	remaining: 6.85s
# 291:	learn: 0.1045078	total: 2.82s	remaining: 6.84s
# 292:	learn: 0.1040829	total: 2.83s	remaining: 6.83s
# 293:	learn: 0.1038246	total: 2.84s	remaining: 6.82s
# 294:	learn: 0.1033611	total: 2.85s	remaining: 6.81s
# 295:	learn: 0.1031774	total: 2.86s	remaining: 6.8s
# 296:	learn: 0.1030088	total: 2.87s	remaining: 6.79s
# 297:	learn: 0.1027672	total: 2.88s	remaining: 6.78s
# 298:	learn: 0.1026221	total: 2.89s	remaining: 6.77s
# 299:	learn: 0.1021710	total: 2.9s	remaining: 6.76s
# 300:	learn: 0.1019459	total: 2.91s	remaining: 6.75s
# 301:	learn: 0.1016311	total: 2.92s	remaining: 6.74s
# 302:	learn: 0.1013847	total: 2.93s	remaining: 6.73s
# 303:	learn: 0.1010726	total: 2.94s	remaining: 6.72s
# 304:	learn: 0.1008374	total: 2.94s	remaining: 6.71s
# 305:	learn: 0.1006615	total: 2.96s	remaining: 6.7s
# 306:	learn: 0.1004390	total: 2.96s	remaining: 6.69s
# 307:	learn: 0.1002477	total: 2.97s	remaining: 6.68s
# 308:	learn: 0.0998932	total: 2.98s	remaining: 6.67s
# 309:	learn: 0.0996088	total: 2.99s	remaining: 6.66s
# 310:	learn: 0.0995046	total: 3s	remaining: 6.65s
# 311:	learn: 0.0992643	total: 3.01s	remaining: 6.64s
# 312:	learn: 0.0989631	total: 3.02s	remaining: 6.63s
# 313:	learn: 0.0987114	total: 3.03s	remaining: 6.62s
# 314:	learn: 0.0983358	total: 3.04s	remaining: 6.61s
# 315:	learn: 0.0979877	total: 3.04s	remaining: 6.59s
# 316:	learn: 0.0976199	total: 3.06s	remaining: 6.58s
# 317:	learn: 0.0973958	total: 3.06s	remaining: 6.57s
# 318:	learn: 0.0969125	total: 3.07s	remaining: 6.56s
# 319:	learn: 0.0965760	total: 3.08s	remaining: 6.55s
# 320:	learn: 0.0963354	total: 3.09s	remaining: 6.54s
# 321:	learn: 0.0961113	total: 3.1s	remaining: 6.53s
# 322:	learn: 0.0959058	total: 3.11s	remaining: 6.52s
# 323:	learn: 0.0956865	total: 3.12s	remaining: 6.51s
# 324:	learn: 0.0954830	total: 3.13s	remaining: 6.49s
# 325:	learn: 0.0950414	total: 3.14s	remaining: 6.48s
# 326:	learn: 0.0947782	total: 3.15s	remaining: 6.47s
# 327:	learn: 0.0945421	total: 3.15s	remaining: 6.46s
# 328:	learn: 0.0941511	total: 3.16s	remaining: 6.44s
# 329:	learn: 0.0939310	total: 3.17s	remaining: 6.43s
# 330:	learn: 0.0938394	total: 3.18s	remaining: 6.42s
# 331:	learn: 0.0935705	total: 3.19s	remaining: 6.41s
# 332:	learn: 0.0934209	total: 3.2s	remaining: 6.4s
# 333:	learn: 0.0929743	total: 3.2s	remaining: 6.39s
# 334:	learn: 0.0927031	total: 3.21s	remaining: 6.38s
# 335:	learn: 0.0925983	total: 3.22s	remaining: 6.37s
# 336:	learn: 0.0924556	total: 3.23s	remaining: 6.36s
# 337:	learn: 0.0920033	total: 3.24s	remaining: 6.35s
# 338:	learn: 0.0917066	total: 3.25s	remaining: 6.34s
# 339:	learn: 0.0915706	total: 3.26s	remaining: 6.33s
# 340:	learn: 0.0913645	total: 3.27s	remaining: 6.31s
# 341:	learn: 0.0909248	total: 3.28s	remaining: 6.3s
# 342:	learn: 0.0904474	total: 3.29s	remaining: 6.29s
# 343:	learn: 0.0902296	total: 3.29s	remaining: 6.28s
# 344:	learn: 0.0898860	total: 3.3s	remaining: 6.27s
# 345:	learn: 0.0895997	total: 3.31s	remaining: 6.26s
# 346:	learn: 0.0893166	total: 3.32s	remaining: 6.25s
# 347:	learn: 0.0890172	total: 3.33s	remaining: 6.24s
# 348:	learn: 0.0886602	total: 3.34s	remaining: 6.23s
# 349:	learn: 0.0884267	total: 3.35s	remaining: 6.22s
# 350:	learn: 0.0882241	total: 3.36s	remaining: 6.21s
# 351:	learn: 0.0878616	total: 3.37s	remaining: 6.2s
# 352:	learn: 0.0876232	total: 3.38s	remaining: 6.2s
# 353:	learn: 0.0874869	total: 3.39s	remaining: 6.19s
# 354:	learn: 0.0873307	total: 3.4s	remaining: 6.18s
# 355:	learn: 0.0870517	total: 3.41s	remaining: 6.17s
# 356:	learn: 0.0867882	total: 3.42s	remaining: 6.16s
# 357:	learn: 0.0865984	total: 3.43s	remaining: 6.15s
# 358:	learn: 0.0864238	total: 3.44s	remaining: 6.13s
# 359:	learn: 0.0862933	total: 3.44s	remaining: 6.13s
# 360:	learn: 0.0860723	total: 3.46s	remaining: 6.12s
# 361:	learn: 0.0858883	total: 3.46s	remaining: 6.11s
# 362:	learn: 0.0856647	total: 3.47s	remaining: 6.09s
# 363:	learn: 0.0853972	total: 3.48s	remaining: 6.08s
# 364:	learn: 0.0852756	total: 3.49s	remaining: 6.07s
# 365:	learn: 0.0849825	total: 3.5s	remaining: 6.06s
# 366:	learn: 0.0848274	total: 3.51s	remaining: 6.05s
# 367:	learn: 0.0847283	total: 3.52s	remaining: 6.04s
# 368:	learn: 0.0845297	total: 3.53s	remaining: 6.03s
# 369:	learn: 0.0842619	total: 3.54s	remaining: 6.02s
# 370:	learn: 0.0841387	total: 3.54s	remaining: 6.01s
# 371:	learn: 0.0838952	total: 3.55s	remaining: 6s
# 372:	learn: 0.0836470	total: 3.56s	remaining: 5.99s
# 373:	learn: 0.0833399	total: 3.57s	remaining: 5.98s
# 374:	learn: 0.0831797	total: 3.58s	remaining: 5.97s
# 375:	learn: 0.0830266	total: 3.59s	remaining: 5.96s
# 376:	learn: 0.0827309	total: 3.6s	remaining: 5.95s
# 377:	learn: 0.0824280	total: 3.61s	remaining: 5.94s
# 378:	learn: 0.0822818	total: 3.62s	remaining: 5.93s
# 379:	learn: 0.0820142	total: 3.63s	remaining: 5.92s
# 380:	learn: 0.0818111	total: 3.64s	remaining: 5.91s
# 381:	learn: 0.0816789	total: 3.65s	remaining: 5.9s
# 382:	learn: 0.0814367	total: 3.65s	remaining: 5.89s
# 383:	learn: 0.0812518	total: 3.66s	remaining: 5.88s
# 384:	learn: 0.0809755	total: 3.67s	remaining: 5.87s
# 385:	learn: 0.0807980	total: 3.68s	remaining: 5.86s
# 386:	learn: 0.0806384	total: 3.69s	remaining: 5.85s
# 387:	learn: 0.0804611	total: 3.7s	remaining: 5.83s
# 388:	learn: 0.0802280	total: 3.71s	remaining: 5.83s
# 389:	learn: 0.0800664	total: 3.72s	remaining: 5.81s
# 390:	learn: 0.0797148	total: 3.73s	remaining: 5.8s
# 391:	learn: 0.0794453	total: 3.73s	remaining: 5.79s
# 392:	learn: 0.0792402	total: 3.74s	remaining: 5.78s
# 393:	learn: 0.0791067	total: 3.75s	remaining: 5.77s
# 394:	learn: 0.0789245	total: 3.76s	remaining: 5.76s
# 395:	learn: 0.0788284	total: 3.77s	remaining: 5.75s
# 396:	learn: 0.0786239	total: 3.78s	remaining: 5.74s
# 397:	learn: 0.0785145	total: 3.79s	remaining: 5.73s
# 398:	learn: 0.0783765	total: 3.8s	remaining: 5.72s
# 399:	learn: 0.0782588	total: 3.81s	remaining: 5.71s
# 400:	learn: 0.0780935	total: 3.82s	remaining: 5.7s
# 401:	learn: 0.0779253	total: 3.83s	remaining: 5.69s
# 402:	learn: 0.0778716	total: 3.84s	remaining: 5.68s
# 403:	learn: 0.0776931	total: 3.85s	remaining: 5.67s
# 404:	learn: 0.0776095	total: 3.85s	remaining: 5.66s
# 405:	learn: 0.0774946	total: 3.86s	remaining: 5.65s
# 406:	learn: 0.0772949	total: 3.87s	remaining: 5.64s
# 407:	learn: 0.0771472	total: 3.88s	remaining: 5.63s
# 408:	learn: 0.0769531	total: 3.89s	remaining: 5.62s
# 409:	learn: 0.0768208	total: 3.9s	remaining: 5.61s
# 410:	learn: 0.0767118	total: 3.91s	remaining: 5.6s
# 411:	learn: 0.0766035	total: 3.92s	remaining: 5.59s
# 412:	learn: 0.0763304	total: 3.93s	remaining: 5.58s
# 413:	learn: 0.0761132	total: 3.94s	remaining: 5.57s
# 414:	learn: 0.0759434	total: 3.95s	remaining: 5.56s
# 415:	learn: 0.0757051	total: 3.96s	remaining: 5.55s
# 416:	learn: 0.0755291	total: 3.96s	remaining: 5.54s
# 417:	learn: 0.0753844	total: 3.97s	remaining: 5.53s
# 418:	learn: 0.0752439	total: 3.98s	remaining: 5.53s
# 419:	learn: 0.0751326	total: 3.99s	remaining: 5.52s
# 420:	learn: 0.0748333	total: 4s	remaining: 5.51s
# 421:	learn: 0.0746097	total: 4.01s	remaining: 5.5s
# 422:	learn: 0.0744651	total: 4.02s	remaining: 5.49s
# 423:	learn: 0.0742067	total: 4.03s	remaining: 5.48s
# 424:	learn: 0.0740918	total: 4.04s	remaining: 5.47s
# 425:	learn: 0.0739835	total: 4.05s	remaining: 5.46s
# 426:	learn: 0.0738506	total: 4.06s	remaining: 5.45s
# 427:	learn: 0.0736848	total: 4.07s	remaining: 5.44s
# 428:	learn: 0.0735649	total: 4.08s	remaining: 5.43s
# 429:	learn: 0.0734642	total: 4.09s	remaining: 5.42s
# 430:	learn: 0.0732920	total: 4.1s	remaining: 5.41s
# 431:	learn: 0.0731573	total: 4.11s	remaining: 5.4s
# 432:	learn: 0.0729452	total: 4.12s	remaining: 5.39s
# 433:	learn: 0.0728014	total: 4.12s	remaining: 5.38s
# 434:	learn: 0.0726384	total: 4.13s	remaining: 5.37s
# 435:	learn: 0.0725246	total: 4.14s	remaining: 5.36s
# 436:	learn: 0.0722568	total: 4.15s	remaining: 5.35s
# 437:	learn: 0.0719852	total: 4.16s	remaining: 5.34s
# 438:	learn: 0.0718492	total: 4.17s	remaining: 5.33s
# 439:	learn: 0.0716422	total: 4.18s	remaining: 5.32s
# 440:	learn: 0.0715512	total: 4.19s	remaining: 5.31s
# 441:	learn: 0.0713963	total: 4.2s	remaining: 5.3s
# 442:	learn: 0.0711442	total: 4.21s	remaining: 5.29s
# 443:	learn: 0.0709212	total: 4.22s	remaining: 5.29s
# 444:	learn: 0.0707974	total: 4.23s	remaining: 5.27s
# 445:	learn: 0.0706490	total: 4.24s	remaining: 5.26s
# 446:	learn: 0.0704723	total: 4.25s	remaining: 5.26s
# 447:	learn: 0.0703899	total: 4.26s	remaining: 5.25s
# 448:	learn: 0.0703081	total: 4.27s	remaining: 5.24s
# 449:	learn: 0.0701228	total: 4.28s	remaining: 5.23s
# 450:	learn: 0.0699890	total: 4.29s	remaining: 5.22s
# 451:	learn: 0.0698845	total: 4.29s	remaining: 5.21s
# 452:	learn: 0.0696277	total: 4.3s	remaining: 5.2s
# 453:	learn: 0.0693585	total: 4.31s	remaining: 5.19s
# 454:	learn: 0.0691597	total: 4.32s	remaining: 5.18s
# 455:	learn: 0.0690412	total: 4.33s	remaining: 5.17s
# 456:	learn: 0.0688278	total: 4.34s	remaining: 5.16s
# 457:	learn: 0.0686989	total: 4.35s	remaining: 5.15s
# 458:	learn: 0.0686284	total: 4.36s	remaining: 5.14s
# 459:	learn: 0.0684833	total: 4.37s	remaining: 5.13s
# 460:	learn: 0.0683708	total: 4.38s	remaining: 5.12s
# 461:	learn: 0.0682716	total: 4.39s	remaining: 5.11s
# 462:	learn: 0.0681692	total: 4.4s	remaining: 5.1s
# 463:	learn: 0.0680919	total: 4.41s	remaining: 5.09s
# 464:	learn: 0.0679340	total: 4.42s	remaining: 5.08s
# 465:	learn: 0.0677545	total: 4.42s	remaining: 5.07s
# 466:	learn: 0.0675701	total: 4.43s	remaining: 5.06s
# 467:	learn: 0.0675183	total: 4.44s	remaining: 5.04s
# 468:	learn: 0.0674113	total: 4.45s	remaining: 5.04s
# 469:	learn: 0.0673067	total: 4.46s	remaining: 5.03s
# 470:	learn: 0.0670486	total: 4.46s	remaining: 5.01s
# 471:	learn: 0.0668762	total: 4.47s	remaining: 5s
# 472:	learn: 0.0667389	total: 4.48s	remaining: 5s
# 473:	learn: 0.0666690	total: 4.49s	remaining: 4.99s
# 474:	learn: 0.0665901	total: 4.5s	remaining: 4.97s
# 475:	learn: 0.0665348	total: 4.51s	remaining: 4.96s
# 476:	learn: 0.0664119	total: 4.51s	remaining: 4.95s
# 477:	learn: 0.0662294	total: 4.52s	remaining: 4.94s
# 478:	learn: 0.0661540	total: 4.53s	remaining: 4.93s
# 479:	learn: 0.0660954	total: 4.54s	remaining: 4.92s
# 480:	learn: 0.0659858	total: 4.55s	remaining: 4.91s
# 481:	learn: 0.0658390	total: 4.56s	remaining: 4.9s
# 482:	learn: 0.0657058	total: 4.57s	remaining: 4.89s
# 483:	learn: 0.0655804	total: 4.58s	remaining: 4.88s
# 484:	learn: 0.0653793	total: 4.59s	remaining: 4.87s
# 485:	learn: 0.0651216	total: 4.6s	remaining: 4.86s
# 486:	learn: 0.0650368	total: 4.61s	remaining: 4.85s
# 487:	learn: 0.0648903	total: 4.62s	remaining: 4.84s
# 488:	learn: 0.0647323	total: 4.63s	remaining: 4.83s
# 489:	learn: 0.0646180	total: 4.63s	remaining: 4.82s
# 490:	learn: 0.0644665	total: 4.64s	remaining: 4.82s
# 491:	learn: 0.0643676	total: 4.65s	remaining: 4.8s
# 492:	learn: 0.0642244	total: 4.66s	remaining: 4.79s
# 493:	learn: 0.0641223	total: 4.67s	remaining: 4.79s
# 494:	learn: 0.0638369	total: 4.68s	remaining: 4.78s
# 495:	learn: 0.0636650	total: 4.69s	remaining: 4.76s
# 496:	learn: 0.0635461	total: 4.7s	remaining: 4.75s
# 497:	learn: 0.0634111	total: 4.71s	remaining: 4.75s
# 498:	learn: 0.0633382	total: 4.72s	remaining: 4.74s
# 499:	learn: 0.0632337	total: 4.73s	remaining: 4.73s
# 500:	learn: 0.0630668	total: 4.74s	remaining: 4.72s
# 501:	learn: 0.0628929	total: 4.74s	remaining: 4.71s
# 502:	learn: 0.0627300	total: 4.75s	remaining: 4.7s
# 503:	learn: 0.0626465	total: 4.76s	remaining: 4.69s
# 504:	learn: 0.0625489	total: 4.77s	remaining: 4.68s
# 505:	learn: 0.0624350	total: 4.78s	remaining: 4.67s
# 506:	learn: 0.0622856	total: 4.79s	remaining: 4.66s
# 507:	learn: 0.0621639	total: 4.8s	remaining: 4.65s
# 508:	learn: 0.0620233	total: 4.81s	remaining: 4.64s
# 509:	learn: 0.0618948	total: 4.82s	remaining: 4.63s
# 510:	learn: 0.0617242	total: 4.83s	remaining: 4.62s
# 511:	learn: 0.0616496	total: 4.84s	remaining: 4.61s
# 512:	learn: 0.0615153	total: 4.84s	remaining: 4.6s
# 513:	learn: 0.0612873	total: 4.85s	remaining: 4.59s
# 514:	learn: 0.0610694	total: 4.86s	remaining: 4.58s
# 515:	learn: 0.0608474	total: 4.87s	remaining: 4.57s
# 516:	learn: 0.0606868	total: 4.88s	remaining: 4.56s
# 517:	learn: 0.0606031	total: 4.89s	remaining: 4.55s
# 518:	learn: 0.0604740	total: 4.9s	remaining: 4.54s
# 519:	learn: 0.0603397	total: 4.91s	remaining: 4.53s
# 520:	learn: 0.0603025	total: 4.92s	remaining: 4.52s
# 521:	learn: 0.0602222	total: 4.93s	remaining: 4.51s
# 522:	learn: 0.0600320	total: 4.93s	remaining: 4.5s
# 523:	learn: 0.0598888	total: 4.94s	remaining: 4.49s
# 524:	learn: 0.0596520	total: 4.95s	remaining: 4.48s
# 525:	learn: 0.0594945	total: 4.96s	remaining: 4.47s
# 526:	learn: 0.0593472	total: 4.97s	remaining: 4.46s
# 527:	learn: 0.0592265	total: 4.98s	remaining: 4.45s
# 528:	learn: 0.0591445	total: 4.99s	remaining: 4.44s
# 529:	learn: 0.0589807	total: 5s	remaining: 4.43s
# 530:	learn: 0.0588626	total: 5.01s	remaining: 4.42s
# 531:	learn: 0.0587860	total: 5.02s	remaining: 4.42s
# 532:	learn: 0.0586956	total: 5.03s	remaining: 4.41s
# 533:	learn: 0.0586224	total: 5.04s	remaining: 4.39s
# 534:	learn: 0.0585287	total: 5.04s	remaining: 4.38s
# 535:	learn: 0.0583859	total: 5.05s	remaining: 4.38s
# 536:	learn: 0.0582019	total: 5.06s	remaining: 4.37s
# 537:	learn: 0.0581542	total: 5.07s	remaining: 4.36s
# 538:	learn: 0.0579853	total: 5.08s	remaining: 4.35s
# 539:	learn: 0.0578799	total: 5.09s	remaining: 4.34s
# 540:	learn: 0.0577252	total: 5.1s	remaining: 4.33s
# 541:	learn: 0.0576156	total: 5.11s	remaining: 4.32s
# 542:	learn: 0.0574448	total: 5.12s	remaining: 4.31s
# 543:	learn: 0.0573086	total: 5.13s	remaining: 4.3s
# 544:	learn: 0.0572202	total: 5.14s	remaining: 4.29s
# 545:	learn: 0.0571469	total: 5.15s	remaining: 4.28s
# 546:	learn: 0.0569986	total: 5.16s	remaining: 4.27s
# 547:	learn: 0.0569116	total: 5.16s	remaining: 4.26s
# 548:	learn: 0.0568021	total: 5.17s	remaining: 4.25s
# 549:	learn: 0.0567222	total: 5.18s	remaining: 4.24s
# 550:	learn: 0.0566421	total: 5.19s	remaining: 4.23s
# 551:	learn: 0.0565164	total: 5.2s	remaining: 4.22s
# 552:	learn: 0.0563188	total: 5.21s	remaining: 4.21s
# 553:	learn: 0.0562312	total: 5.22s	remaining: 4.2s
# 554:	learn: 0.0561365	total: 5.23s	remaining: 4.2s
# 555:	learn: 0.0560477	total: 5.24s	remaining: 4.18s
# 556:	learn: 0.0559729	total: 5.25s	remaining: 4.18s
# 557:	learn: 0.0559079	total: 5.26s	remaining: 4.17s
# 558:	learn: 0.0558299	total: 5.27s	remaining: 4.16s
# 559:	learn: 0.0557375	total: 5.28s	remaining: 4.15s
# 560:	learn: 0.0556633	total: 5.29s	remaining: 4.14s
# 561:	learn: 0.0555520	total: 5.3s	remaining: 4.13s
# 562:	learn: 0.0554536	total: 5.31s	remaining: 4.12s
# 563:	learn: 0.0553468	total: 5.32s	remaining: 4.11s
# 564:	learn: 0.0551352	total: 5.32s	remaining: 4.1s
# 565:	learn: 0.0549934	total: 5.33s	remaining: 4.09s
# 566:	learn: 0.0549125	total: 5.34s	remaining: 4.08s
# 567:	learn: 0.0548359	total: 5.35s	remaining: 4.07s
# 568:	learn: 0.0547302	total: 5.36s	remaining: 4.06s
# 569:	learn: 0.0545468	total: 5.37s	remaining: 4.05s
# 570:	learn: 0.0544720	total: 5.38s	remaining: 4.04s
# 571:	learn: 0.0543740	total: 5.39s	remaining: 4.03s
# 572:	learn: 0.0542230	total: 5.4s	remaining: 4.02s
# 573:	learn: 0.0540992	total: 5.41s	remaining: 4.01s
# 574:	learn: 0.0540147	total: 5.42s	remaining: 4s
# 575:	learn: 0.0538386	total: 5.43s	remaining: 3.99s
# 576:	learn: 0.0537262	total: 5.43s	remaining: 3.98s
# 577:	learn: 0.0536498	total: 5.44s	remaining: 3.97s
# 578:	learn: 0.0535107	total: 5.45s	remaining: 3.96s
# 579:	learn: 0.0534309	total: 5.46s	remaining: 3.96s
# 580:	learn: 0.0532982	total: 5.47s	remaining: 3.94s
# 581:	learn: 0.0532416	total: 5.48s	remaining: 3.94s
# 582:	learn: 0.0531630	total: 5.49s	remaining: 3.92s
# 583:	learn: 0.0530341	total: 5.5s	remaining: 3.92s
# 584:	learn: 0.0529149	total: 5.51s	remaining: 3.91s
# 585:	learn: 0.0528211	total: 5.52s	remaining: 3.9s
# 586:	learn: 0.0526953	total: 5.53s	remaining: 3.89s
# 587:	learn: 0.0526622	total: 5.53s	remaining: 3.88s
# 588:	learn: 0.0526086	total: 5.54s	remaining: 3.87s
# 589:	learn: 0.0525211	total: 5.55s	remaining: 3.86s
# 590:	learn: 0.0524081	total: 5.56s	remaining: 3.85s
# 591:	learn: 0.0522363	total: 5.57s	remaining: 3.84s
# 592:	learn: 0.0521555	total: 5.58s	remaining: 3.83s
# 593:	learn: 0.0520717	total: 5.59s	remaining: 3.82s
# 594:	learn: 0.0519662	total: 5.6s	remaining: 3.81s
# 595:	learn: 0.0518189	total: 5.61s	remaining: 3.8s
# 596:	learn: 0.0517136	total: 5.62s	remaining: 3.79s
# 597:	learn: 0.0516674	total: 5.63s	remaining: 3.78s
# 598:	learn: 0.0516055	total: 5.64s	remaining: 3.77s
# 599:	learn: 0.0515304	total: 5.65s	remaining: 3.76s
# 600:	learn: 0.0514378	total: 5.66s	remaining: 3.75s
# 601:	learn: 0.0513182	total: 5.66s	remaining: 3.75s
# 602:	learn: 0.0512463	total: 5.67s	remaining: 3.73s
# 603:	learn: 0.0511625	total: 5.68s	remaining: 3.73s
# 604:	learn: 0.0510309	total: 5.69s	remaining: 3.72s
# 605:	learn: 0.0508775	total: 5.7s	remaining: 3.71s
# 606:	learn: 0.0507212	total: 5.71s	remaining: 3.7s
# 607:	learn: 0.0505508	total: 5.72s	remaining: 3.69s
# 608:	learn: 0.0504507	total: 5.73s	remaining: 3.68s
# 609:	learn: 0.0504201	total: 5.74s	remaining: 3.67s
# 610:	learn: 0.0503349	total: 5.75s	remaining: 3.66s
# 611:	learn: 0.0502893	total: 5.76s	remaining: 3.65s
# 612:	learn: 0.0502424	total: 5.77s	remaining: 3.64s
# 613:	learn: 0.0501205	total: 5.78s	remaining: 3.63s
# 614:	learn: 0.0500251	total: 5.79s	remaining: 3.62s
# 615:	learn: 0.0499504	total: 5.8s	remaining: 3.61s
# 616:	learn: 0.0498829	total: 5.8s	remaining: 3.6s
# 617:	learn: 0.0497139	total: 5.82s	remaining: 3.59s
# 618:	learn: 0.0496259	total: 5.82s	remaining: 3.58s
# 619:	learn: 0.0495673	total: 5.83s	remaining: 3.58s
# 620:	learn: 0.0494656	total: 5.84s	remaining: 3.57s
# 621:	learn: 0.0494019	total: 5.85s	remaining: 3.56s
# 622:	learn: 0.0492840	total: 5.86s	remaining: 3.55s
# 623:	learn: 0.0491588	total: 5.87s	remaining: 3.54s
# 624:	learn: 0.0489671	total: 5.88s	remaining: 3.53s
# 625:	learn: 0.0489142	total: 5.89s	remaining: 3.52s
# 626:	learn: 0.0487342	total: 5.9s	remaining: 3.51s
# 627:	learn: 0.0486907	total: 5.91s	remaining: 3.5s
# 628:	learn: 0.0486310	total: 5.92s	remaining: 3.49s
# 629:	learn: 0.0485677	total: 5.92s	remaining: 3.48s
# 630:	learn: 0.0485487	total: 5.93s	remaining: 3.47s
# 631:	learn: 0.0484923	total: 5.94s	remaining: 3.46s
# 632:	learn: 0.0484261	total: 5.95s	remaining: 3.45s
# 633:	learn: 0.0483034	total: 5.96s	remaining: 3.44s
# 634:	learn: 0.0482326	total: 5.97s	remaining: 3.43s
# 635:	learn: 0.0480553	total: 5.97s	remaining: 3.42s
# 636:	learn: 0.0479926	total: 5.99s	remaining: 3.41s
# 637:	learn: 0.0479691	total: 5.99s	remaining: 3.4s
# 638:	learn: 0.0478850	total: 6s	remaining: 3.39s
# 639:	learn: 0.0478164	total: 6.01s	remaining: 3.38s
# 640:	learn: 0.0477475	total: 6.02s	remaining: 3.37s
# 641:	learn: 0.0476048	total: 6.03s	remaining: 3.36s
# 642:	learn: 0.0475336	total: 6.04s	remaining: 3.35s
# 643:	learn: 0.0474864	total: 6.05s	remaining: 3.34s
# 644:	learn: 0.0473071	total: 6.06s	remaining: 3.33s
# 645:	learn: 0.0472060	total: 6.07s	remaining: 3.32s
# 646:	learn: 0.0471477	total: 6.07s	remaining: 3.31s
# 647:	learn: 0.0470846	total: 6.08s	remaining: 3.3s
# 648:	learn: 0.0469946	total: 6.09s	remaining: 3.29s
# 649:	learn: 0.0468720	total: 6.1s	remaining: 3.29s
# 650:	learn: 0.0467773	total: 6.11s	remaining: 3.28s
# 651:	learn: 0.0467241	total: 6.12s	remaining: 3.27s
# 652:	learn: 0.0466672	total: 6.13s	remaining: 3.26s
# 653:	learn: 0.0465960	total: 6.14s	remaining: 3.25s
# 654:	learn: 0.0465517	total: 6.15s	remaining: 3.24s
# 655:	learn: 0.0464216	total: 6.16s	remaining: 3.23s
# 656:	learn: 0.0463293	total: 6.17s	remaining: 3.22s
# 657:	learn: 0.0462734	total: 6.18s	remaining: 3.21s
# 658:	learn: 0.0460951	total: 6.19s	remaining: 3.2s
# 659:	learn: 0.0459950	total: 6.2s	remaining: 3.19s
# 660:	learn: 0.0459531	total: 6.21s	remaining: 3.18s
# 661:	learn: 0.0458368	total: 6.21s	remaining: 3.17s
# 662:	learn: 0.0457194	total: 6.22s	remaining: 3.16s
# 663:	learn: 0.0456475	total: 6.23s	remaining: 3.15s
# 664:	learn: 0.0455375	total: 6.24s	remaining: 3.15s
# 665:	learn: 0.0454380	total: 6.25s	remaining: 3.13s
# 666:	learn: 0.0453926	total: 6.26s	remaining: 3.13s
# 667:	learn: 0.0453507	total: 6.27s	remaining: 3.12s
# 668:	learn: 0.0452766	total: 6.28s	remaining: 3.11s
# 669:	learn: 0.0452037	total: 6.29s	remaining: 3.1s
# 670:	learn: 0.0451615	total: 6.3s	remaining: 3.09s
# 671:	learn: 0.0451089	total: 6.31s	remaining: 3.08s
# 672:	learn: 0.0448992	total: 6.32s	remaining: 3.07s
# 673:	learn: 0.0448395	total: 6.32s	remaining: 3.06s
# 674:	learn: 0.0447941	total: 6.33s	remaining: 3.05s
# 675:	learn: 0.0447477	total: 6.34s	remaining: 3.04s
# 676:	learn: 0.0447130	total: 6.35s	remaining: 3.03s
# 677:	learn: 0.0446307	total: 6.36s	remaining: 3.02s
# 678:	learn: 0.0445644	total: 6.37s	remaining: 3.01s
# 679:	learn: 0.0445214	total: 6.38s	remaining: 3s
# 680:	learn: 0.0444474	total: 6.39s	remaining: 2.99s
# 681:	learn: 0.0443791	total: 6.4s	remaining: 2.98s
# 682:	learn: 0.0443301	total: 6.41s	remaining: 2.97s
# 683:	learn: 0.0442065	total: 6.42s	remaining: 2.96s
# 684:	learn: 0.0441135	total: 6.43s	remaining: 2.96s
# 685:	learn: 0.0440225	total: 6.44s	remaining: 2.95s
# 686:	learn: 0.0439294	total: 6.45s	remaining: 2.94s
# 687:	learn: 0.0438397	total: 6.45s	remaining: 2.93s
# 688:	learn: 0.0438051	total: 6.46s	remaining: 2.92s
# 689:	learn: 0.0437799	total: 6.47s	remaining: 2.9s
# 690:	learn: 0.0437540	total: 6.48s	remaining: 2.9s
# 691:	learn: 0.0436595	total: 6.49s	remaining: 2.89s
# 692:	learn: 0.0436276	total: 6.49s	remaining: 2.88s
# 693:	learn: 0.0435831	total: 6.5s	remaining: 2.87s
# 694:	learn: 0.0434988	total: 6.51s	remaining: 2.86s
# 695:	learn: 0.0434068	total: 6.52s	remaining: 2.85s
# 696:	learn: 0.0433640	total: 6.53s	remaining: 2.84s
# 697:	learn: 0.0432822	total: 6.54s	remaining: 2.83s
# 698:	learn: 0.0431902	total: 6.55s	remaining: 2.82s
# 699:	learn: 0.0430971	total: 6.56s	remaining: 2.81s
# 700:	learn: 0.0429964	total: 6.57s	remaining: 2.8s
# 701:	learn: 0.0429153	total: 6.58s	remaining: 2.79s
# 702:	learn: 0.0427072	total: 6.58s	remaining: 2.78s
# 703:	learn: 0.0426572	total: 6.59s	remaining: 2.77s
# 704:	learn: 0.0426087	total: 6.6s	remaining: 2.76s
# 705:	learn: 0.0425545	total: 6.61s	remaining: 2.75s
# 706:	learn: 0.0425129	total: 6.62s	remaining: 2.74s
# 707:	learn: 0.0424289	total: 6.63s	remaining: 2.73s
# 708:	learn: 0.0423984	total: 6.64s	remaining: 2.72s
# 709:	learn: 0.0423382	total: 6.65s	remaining: 2.71s
# 710:	learn: 0.0422418	total: 6.66s	remaining: 2.71s
# 711:	learn: 0.0421127	total: 6.67s	remaining: 2.7s
# 712:	learn: 0.0419885	total: 6.67s	remaining: 2.69s
# 713:	learn: 0.0418941	total: 6.68s	remaining: 2.68s
# 714:	learn: 0.0418402	total: 6.69s	remaining: 2.67s
# 715:	learn: 0.0417884	total: 6.7s	remaining: 2.66s
# 716:	learn: 0.0417123	total: 6.71s	remaining: 2.65s
# 717:	learn: 0.0416835	total: 6.72s	remaining: 2.64s
# 718:	learn: 0.0416345	total: 6.73s	remaining: 2.63s
# 719:	learn: 0.0415688	total: 6.74s	remaining: 2.62s
# 720:	learn: 0.0414797	total: 6.75s	remaining: 2.61s
# 721:	learn: 0.0414381	total: 6.76s	remaining: 2.6s
# 722:	learn: 0.0413595	total: 6.77s	remaining: 2.59s
# 723:	learn: 0.0412303	total: 6.78s	remaining: 2.58s
# 724:	learn: 0.0411991	total: 6.79s	remaining: 2.57s
# 725:	learn: 0.0411241	total: 6.8s	remaining: 2.56s
# 726:	learn: 0.0410657	total: 6.81s	remaining: 2.56s
# 727:	learn: 0.0410260	total: 6.81s	remaining: 2.55s
# 728:	learn: 0.0409647	total: 6.82s	remaining: 2.54s
# 729:	learn: 0.0409326	total: 6.83s	remaining: 2.53s
# 730:	learn: 0.0408684	total: 6.84s	remaining: 2.52s
# 731:	learn: 0.0408242	total: 6.85s	remaining: 2.51s
# 732:	learn: 0.0407643	total: 6.86s	remaining: 2.5s
# 733:	learn: 0.0406618	total: 6.87s	remaining: 2.49s
# 734:	learn: 0.0406293	total: 6.88s	remaining: 2.48s
# 735:	learn: 0.0405168	total: 6.89s	remaining: 2.47s
# 736:	learn: 0.0404129	total: 6.9s	remaining: 2.46s
# 737:	learn: 0.0403378	total: 6.9s	remaining: 2.45s
# 738:	learn: 0.0402593	total: 6.91s	remaining: 2.44s
# 739:	learn: 0.0401199	total: 6.92s	remaining: 2.43s
# 740:	learn: 0.0400549	total: 6.93s	remaining: 2.42s
# 741:	learn: 0.0400095	total: 6.94s	remaining: 2.41s
# 742:	learn: 0.0399750	total: 6.95s	remaining: 2.4s
# 743:	learn: 0.0399074	total: 6.96s	remaining: 2.39s
# 744:	learn: 0.0398513	total: 6.97s	remaining: 2.38s
# 745:	learn: 0.0398218	total: 6.98s	remaining: 2.38s
# 746:	learn: 0.0397273	total: 6.99s	remaining: 2.37s
# 747:	learn: 0.0396608	total: 7s	remaining: 2.36s
# 748:	learn: 0.0395556	total: 7s	remaining: 2.35s
# 749:	learn: 0.0394693	total: 7.01s	remaining: 2.34s
# 750:	learn: 0.0394013	total: 7.02s	remaining: 2.33s
# 751:	learn: 0.0393161	total: 7.03s	remaining: 2.32s
# 752:	learn: 0.0392734	total: 7.04s	remaining: 2.31s
# 753:	learn: 0.0391996	total: 7.05s	remaining: 2.3s
# 754:	learn: 0.0391204	total: 7.06s	remaining: 2.29s
# 755:	learn: 0.0390635	total: 7.07s	remaining: 2.28s
# 756:	learn: 0.0390525	total: 7.08s	remaining: 2.27s
# 757:	learn: 0.0389653	total: 7.09s	remaining: 2.26s
# 758:	learn: 0.0388871	total: 7.1s	remaining: 2.25s
# 759:	learn: 0.0388186	total: 7.11s	remaining: 2.24s
# 760:	learn: 0.0387190	total: 7.11s	remaining: 2.23s
# 761:	learn: 0.0386762	total: 7.12s	remaining: 2.22s
# 762:	learn: 0.0386379	total: 7.13s	remaining: 2.21s
# 763:	learn: 0.0385864	total: 7.14s	remaining: 2.21s
# 764:	learn: 0.0385119	total: 7.15s	remaining: 2.2s
# 765:	learn: 0.0384638	total: 7.16s	remaining: 2.19s
# 766:	learn: 0.0383831	total: 7.17s	remaining: 2.18s
# 767:	learn: 0.0383219	total: 7.18s	remaining: 2.17s
# 768:	learn: 0.0382531	total: 7.19s	remaining: 2.16s
# 769:	learn: 0.0381845	total: 7.2s	remaining: 2.15s
# 770:	learn: 0.0381365	total: 7.21s	remaining: 2.14s
# 771:	learn: 0.0380761	total: 7.22s	remaining: 2.13s
# 772:	learn: 0.0380267	total: 7.23s	remaining: 2.12s
# 773:	learn: 0.0379564	total: 7.24s	remaining: 2.11s
# 774:	learn: 0.0378840	total: 7.24s	remaining: 2.1s
# 775:	learn: 0.0378564	total: 7.25s	remaining: 2.09s
# 776:	learn: 0.0378040	total: 7.26s	remaining: 2.08s
# 777:	learn: 0.0377480	total: 7.26s	remaining: 2.07s
# 778:	learn: 0.0376857	total: 7.28s	remaining: 2.06s
# 779:	learn: 0.0376094	total: 7.28s	remaining: 2.05s
# 780:	learn: 0.0375835	total: 7.29s	remaining: 2.04s
# 781:	learn: 0.0375079	total: 7.3s	remaining: 2.04s
# 782:	learn: 0.0374716	total: 7.31s	remaining: 2.03s
# 783:	learn: 0.0373825	total: 7.32s	remaining: 2.02s
# 784:	learn: 0.0373162	total: 7.33s	remaining: 2.01s
# 785:	learn: 0.0372922	total: 7.34s	remaining: 2s
# 786:	learn: 0.0372512	total: 7.35s	remaining: 1.99s
# 787:	learn: 0.0372168	total: 7.36s	remaining: 1.98s
# 788:	learn: 0.0371621	total: 7.37s	remaining: 1.97s
# 789:	learn: 0.0371216	total: 7.38s	remaining: 1.96s
# 790:	learn: 0.0371066	total: 7.39s	remaining: 1.95s
# 791:	learn: 0.0370423	total: 7.4s	remaining: 1.94s
# 792:	learn: 0.0369862	total: 7.41s	remaining: 1.93s
# 793:	learn: 0.0369520	total: 7.42s	remaining: 1.92s
# 794:	learn: 0.0368817	total: 7.43s	remaining: 1.92s
# 795:	learn: 0.0367919	total: 7.44s	remaining: 1.91s
# 796:	learn: 0.0367374	total: 7.45s	remaining: 1.9s
# 797:	learn: 0.0367098	total: 7.46s	remaining: 1.89s
# 798:	learn: 0.0366673	total: 7.47s	remaining: 1.88s
# 799:	learn: 0.0365931	total: 7.47s	remaining: 1.87s
# 800:	learn: 0.0364942	total: 7.48s	remaining: 1.86s
# 801:	learn: 0.0364533	total: 7.49s	remaining: 1.85s
# 802:	learn: 0.0363840	total: 7.5s	remaining: 1.84s
# 803:	learn: 0.0363566	total: 7.51s	remaining: 1.83s
# 804:	learn: 0.0362820	total: 7.52s	remaining: 1.82s
# 805:	learn: 0.0362353	total: 7.53s	remaining: 1.81s
# 806:	learn: 0.0361602	total: 7.54s	remaining: 1.8s
# 807:	learn: 0.0361163	total: 7.55s	remaining: 1.79s
# 808:	learn: 0.0360720	total: 7.56s	remaining: 1.78s
# 809:	learn: 0.0360497	total: 7.57s	remaining: 1.77s
# 810:	learn: 0.0359845	total: 7.58s	remaining: 1.76s
# 811:	learn: 0.0359336	total: 7.58s	remaining: 1.76s
# 812:	learn: 0.0358747	total: 7.59s	remaining: 1.75s
# 813:	learn: 0.0357993	total: 7.6s	remaining: 1.74s
# 814:	learn: 0.0357436	total: 7.61s	remaining: 1.73s
# 815:	learn: 0.0356654	total: 7.62s	remaining: 1.72s
# 816:	learn: 0.0356366	total: 7.63s	remaining: 1.71s
# 817:	learn: 0.0356005	total: 7.64s	remaining: 1.7s
# 818:	learn: 0.0355523	total: 7.65s	remaining: 1.69s
# 819:	learn: 0.0354992	total: 7.66s	remaining: 1.68s
# 820:	learn: 0.0354413	total: 7.67s	remaining: 1.67s
# 821:	learn: 0.0354067	total: 7.68s	remaining: 1.66s
# 822:	learn: 0.0352994	total: 7.69s	remaining: 1.65s
# 823:	learn: 0.0352789	total: 7.7s	remaining: 1.64s
# 824:	learn: 0.0352212	total: 7.71s	remaining: 1.63s
# 825:	learn: 0.0351471	total: 7.71s	remaining: 1.63s
# 826:	learn: 0.0351040	total: 7.72s	remaining: 1.61s
# 827:	learn: 0.0350695	total: 7.73s	remaining: 1.61s
# 828:	learn: 0.0350461	total: 7.74s	remaining: 1.6s
# 829:	learn: 0.0350243	total: 7.75s	remaining: 1.59s
# 830:	learn: 0.0349381	total: 7.76s	remaining: 1.58s
# 831:	learn: 0.0348875	total: 7.77s	remaining: 1.57s
# 832:	learn: 0.0348304	total: 7.78s	remaining: 1.56s
# 833:	learn: 0.0347819	total: 7.79s	remaining: 1.55s
# 834:	learn: 0.0346743	total: 7.8s	remaining: 1.54s
# 835:	learn: 0.0346360	total: 7.81s	remaining: 1.53s
# 836:	learn: 0.0345963	total: 7.82s	remaining: 1.52s
# 837:	learn: 0.0345613	total: 7.83s	remaining: 1.51s
# 838:	learn: 0.0345001	total: 7.83s	remaining: 1.5s
# 839:	learn: 0.0344676	total: 7.84s	remaining: 1.49s
# 840:	learn: 0.0344180	total: 7.85s	remaining: 1.48s
# 841:	learn: 0.0343690	total: 7.86s	remaining: 1.48s
# 842:	learn: 0.0343422	total: 7.87s	remaining: 1.47s
# 843:	learn: 0.0343243	total: 7.88s	remaining: 1.46s
# 844:	learn: 0.0343145	total: 7.89s	remaining: 1.45s
# 845:	learn: 0.0342810	total: 7.9s	remaining: 1.44s
# 846:	learn: 0.0342551	total: 7.91s	remaining: 1.43s
# 847:	learn: 0.0342235	total: 7.92s	remaining: 1.42s
# 848:	learn: 0.0341185	total: 7.92s	remaining: 1.41s
# 849:	learn: 0.0340889	total: 7.93s	remaining: 1.4s
# 850:	learn: 0.0340266	total: 7.94s	remaining: 1.39s
# 851:	learn: 0.0339992	total: 7.95s	remaining: 1.38s
# 852:	learn: 0.0339664	total: 7.96s	remaining: 1.37s
# 853:	learn: 0.0338703	total: 7.97s	remaining: 1.36s
# 854:	learn: 0.0338454	total: 7.98s	remaining: 1.35s
# 855:	learn: 0.0337922	total: 7.99s	remaining: 1.34s
# 856:	learn: 0.0337267	total: 8s	remaining: 1.33s
# 857:	learn: 0.0336776	total: 8.01s	remaining: 1.32s
# 858:	learn: 0.0336419	total: 8.02s	remaining: 1.31s
# 859:	learn: 0.0335982	total: 8.03s	remaining: 1.31s
# 860:	learn: 0.0335233	total: 8.04s	remaining: 1.3s
# 861:	learn: 0.0334870	total: 8.04s	remaining: 1.29s
# 862:	learn: 0.0334413	total: 8.05s	remaining: 1.28s
# 863:	learn: 0.0333908	total: 8.06s	remaining: 1.27s
# 864:	learn: 0.0333413	total: 8.07s	remaining: 1.26s
# 865:	learn: 0.0332966	total: 8.08s	remaining: 1.25s
# 866:	learn: 0.0332638	total: 8.09s	remaining: 1.24s
# 867:	learn: 0.0332094	total: 8.1s	remaining: 1.23s
# 868:	learn: 0.0331765	total: 8.11s	remaining: 1.22s
# 869:	learn: 0.0331098	total: 8.11s	remaining: 1.21s
# 870:	learn: 0.0330643	total: 8.12s	remaining: 1.2s
# 871:	learn: 0.0330444	total: 8.13s	remaining: 1.19s
# 872:	learn: 0.0330203	total: 8.14s	remaining: 1.18s
# 873:	learn: 0.0329609	total: 8.15s	remaining: 1.18s
# 874:	learn: 0.0329213	total: 8.16s	remaining: 1.17s
# 875:	learn: 0.0328948	total: 8.17s	remaining: 1.16s
# 876:	learn: 0.0328070	total: 8.18s	remaining: 1.15s
# 877:	learn: 0.0327419	total: 8.19s	remaining: 1.14s
# 878:	learn: 0.0327088	total: 8.2s	remaining: 1.13s
# 879:	learn: 0.0326861	total: 8.21s	remaining: 1.12s
# 880:	learn: 0.0326554	total: 8.22s	remaining: 1.11s
# 881:	learn: 0.0326322	total: 8.23s	remaining: 1.1s
# 882:	learn: 0.0326002	total: 8.24s	remaining: 1.09s
# 883:	learn: 0.0325132	total: 8.25s	remaining: 1.08s
# 884:	learn: 0.0324975	total: 8.26s	remaining: 1.07s
# 885:	learn: 0.0324253	total: 8.27s	remaining: 1.06s
# 886:	learn: 0.0323818	total: 8.28s	remaining: 1.05s
# 887:	learn: 0.0323330	total: 8.28s	remaining: 1.04s
# 888:	learn: 0.0323240	total: 8.29s	remaining: 1.03s
# 889:	learn: 0.0322863	total: 8.3s	remaining: 1.03s
# 890:	learn: 0.0322429	total: 8.31s	remaining: 1.02s
# 891:	learn: 0.0321755	total: 8.32s	remaining: 1.01s
# 892:	learn: 0.0321488	total: 8.33s	remaining: 998ms
# 893:	learn: 0.0320961	total: 8.34s	remaining: 989ms
# 894:	learn: 0.0320784	total: 8.35s	remaining: 980ms
# 895:	learn: 0.0320422	total: 8.36s	remaining: 970ms
# 896:	learn: 0.0319900	total: 8.37s	remaining: 961ms
# 897:	learn: 0.0319799	total: 8.38s	remaining: 952ms
# 898:	learn: 0.0319691	total: 8.39s	remaining: 942ms
# 899:	learn: 0.0319401	total: 8.39s	remaining: 933ms
# 900:	learn: 0.0318801	total: 8.4s	remaining: 923ms
# 901:	learn: 0.0318562	total: 8.41s	remaining: 914ms
# 902:	learn: 0.0317719	total: 8.42s	remaining: 905ms
# 903:	learn: 0.0317493	total: 8.43s	remaining: 895ms
# 904:	learn: 0.0317191	total: 8.44s	remaining: 886ms
# 905:	learn: 0.0316577	total: 8.45s	remaining: 877ms
# 906:	learn: 0.0315973	total: 8.46s	remaining: 868ms
# 907:	learn: 0.0315472	total: 8.47s	remaining: 858ms
# 908:	learn: 0.0315053	total: 8.48s	remaining: 849ms
# 909:	learn: 0.0314650	total: 8.49s	remaining: 839ms
# 910:	learn: 0.0314186	total: 8.5s	remaining: 830ms
# 911:	learn: 0.0313834	total: 8.51s	remaining: 821ms
# 912:	learn: 0.0313222	total: 8.52s	remaining: 811ms
# 913:	learn: 0.0312453	total: 8.52s	remaining: 802ms
# 914:	learn: 0.0311784	total: 8.53s	remaining: 793ms
# 915:	learn: 0.0311594	total: 8.54s	remaining: 784ms
# 916:	learn: 0.0311379	total: 8.55s	remaining: 774ms
# 917:	learn: 0.0310917	total: 8.56s	remaining: 765ms
# 918:	learn: 0.0310228	total: 8.57s	remaining: 756ms
# 919:	learn: 0.0309669	total: 8.58s	remaining: 746ms
# 920:	learn: 0.0309274	total: 8.59s	remaining: 737ms
# 921:	learn: 0.0309142	total: 8.6s	remaining: 728ms
# 922:	learn: 0.0308732	total: 8.61s	remaining: 718ms
# 923:	learn: 0.0308377	total: 8.62s	remaining: 709ms
# 924:	learn: 0.0307860	total: 8.63s	remaining: 700ms
# 925:	learn: 0.0307438	total: 8.64s	remaining: 690ms
# 926:	learn: 0.0306969	total: 8.65s	remaining: 681ms
# 927:	learn: 0.0306771	total: 8.66s	remaining: 672ms
# 928:	learn: 0.0306493	total: 8.66s	remaining: 662ms
# 929:	learn: 0.0306300	total: 8.67s	remaining: 653ms
# 930:	learn: 0.0306003	total: 8.68s	remaining: 644ms
# 931:	learn: 0.0305675	total: 8.69s	remaining: 634ms
# 932:	learn: 0.0304723	total: 8.7s	remaining: 625ms
# 933:	learn: 0.0304224	total: 8.71s	remaining: 616ms
# 934:	learn: 0.0303657	total: 8.72s	remaining: 606ms
# 935:	learn: 0.0303173	total: 8.73s	remaining: 597ms
# 936:	learn: 0.0302650	total: 8.74s	remaining: 588ms
# 937:	learn: 0.0302309	total: 8.75s	remaining: 578ms
# 938:	learn: 0.0301970	total: 8.76s	remaining: 569ms
# 939:	learn: 0.0301750	total: 8.77s	remaining: 560ms
# 940:	learn: 0.0301443	total: 8.78s	remaining: 550ms
# 941:	learn: 0.0300897	total: 8.79s	remaining: 541ms
# 942:	learn: 0.0300597	total: 8.79s	remaining: 532ms
# 943:	learn: 0.0300345	total: 8.8s	remaining: 522ms
# 944:	learn: 0.0299960	total: 8.81s	remaining: 513ms
# 945:	learn: 0.0299547	total: 8.82s	remaining: 504ms
# 946:	learn: 0.0298969	total: 8.83s	remaining: 494ms
# 947:	learn: 0.0298544	total: 8.84s	remaining: 485ms
# 948:	learn: 0.0298054	total: 8.85s	remaining: 476ms
# 949:	learn: 0.0297521	total: 8.86s	remaining: 466ms
# 950:	learn: 0.0296915	total: 8.87s	remaining: 457ms
# 951:	learn: 0.0296636	total: 8.88s	remaining: 448ms
# 952:	learn: 0.0296197	total: 8.89s	remaining: 438ms
# 953:	learn: 0.0295833	total: 8.89s	remaining: 429ms
# 954:	learn: 0.0295093	total: 8.9s	remaining: 420ms
# 955:	learn: 0.0294641	total: 8.91s	remaining: 410ms
# 956:	learn: 0.0294304	total: 8.92s	remaining: 401ms
# 957:	learn: 0.0293805	total: 8.93s	remaining: 392ms
# 958:	learn: 0.0293554	total: 8.94s	remaining: 382ms
# 959:	learn: 0.0293194	total: 8.95s	remaining: 373ms
# 960:	learn: 0.0292350	total: 8.96s	remaining: 364ms
# 961:	learn: 0.0292083	total: 8.97s	remaining: 354ms
# 962:	learn: 0.0291419	total: 8.98s	remaining: 345ms
# 963:	learn: 0.0291067	total: 8.99s	remaining: 336ms
# 964:	learn: 0.0290799	total: 9s	remaining: 326ms
# 965:	learn: 0.0290394	total: 9.01s	remaining: 317ms
# 966:	learn: 0.0290020	total: 9.01s	remaining: 308ms
# 967:	learn: 0.0289754	total: 9.02s	remaining: 298ms
# 968:	learn: 0.0289411	total: 9.03s	remaining: 289ms
# 969:	learn: 0.0288849	total: 9.04s	remaining: 280ms
# 970:	learn: 0.0288473	total: 9.05s	remaining: 270ms
# 971:	learn: 0.0288017	total: 9.06s	remaining: 261ms
# 972:	learn: 0.0287746	total: 9.07s	remaining: 252ms
# 973:	learn: 0.0287042	total: 9.08s	remaining: 242ms
# 974:	learn: 0.0286872	total: 9.09s	remaining: 233ms
# 975:	learn: 0.0286673	total: 9.1s	remaining: 224ms
# 976:	learn: 0.0286538	total: 9.1s	remaining: 214ms
# 977:	learn: 0.0286309	total: 9.11s	remaining: 205ms
# 978:	learn: 0.0285721	total: 9.12s	remaining: 196ms
# 979:	learn: 0.0285474	total: 9.13s	remaining: 186ms
# 980:	learn: 0.0285184	total: 9.14s	remaining: 177ms
# 981:	learn: 0.0284805	total: 9.15s	remaining: 168ms
# 982:	learn: 0.0284480	total: 9.16s	remaining: 158ms
# 983:	learn: 0.0284246	total: 9.17s	remaining: 149ms
# 984:	learn: 0.0284054	total: 9.18s	remaining: 140ms
# 985:	learn: 0.0283606	total: 9.19s	remaining: 130ms
# 986:	learn: 0.0283320	total: 9.2s	remaining: 121ms
# 987:	learn: 0.0283246	total: 9.21s	remaining: 112ms
# 988:	learn: 0.0282833	total: 9.21s	remaining: 102ms
# 989:	learn: 0.0282512	total: 9.22s	remaining: 93.2ms
# 990:	learn: 0.0282049	total: 9.23s	remaining: 83.9ms
# 991:	learn: 0.0281786	total: 9.28s	remaining: 74.8ms
# 992:	learn: 0.0281593	total: 9.32s	remaining: 65.7ms
# 993:	learn: 0.0280704	total: 9.33s	remaining: 56.3ms
# 994:	learn: 0.0280563	total: 9.35s	remaining: 47ms
# 995:	learn: 0.0280464	total: 9.36s	remaining: 37.6ms
# 996:	learn: 0.0280242	total: 9.37s	remaining: 28.2ms
# 997:	learn: 0.0280071	total: 9.38s	remaining: 18.8ms
# 998:	learn: 0.0279974	total: 9.39s	remaining: 9.4ms
# 999:	learn: 0.0279572	total: 9.39s	remaining: 0us

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print ("Accuracy : ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy :  0.9337078651685393

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)

print ("Confusion Matrix : \n", cm)
# Out:
# Confusion Matrix :
#  [[353  23   6   0]
#  [ 17 347   5   0]
#  [  0   6 131   0]
#  [  0   0   2   0]]

# %%
from sklearn.metrics import confusion_matrix,accuracy_score, classification_report
print(classification_report(y_test,y_pred, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94       382
#            1       0.92      0.94      0.93       369
#            2       0.91      0.96      0.93       137
#            3       1.00      0.00      0.00         2
#
#     accuracy                           0.93       890
#    macro avg       0.95      0.71      0.70       890
# weighted avg       0.93      0.93      0.93       890

# %%
from sklearn.preprocessing import LabelBinarizer

label_binarizer = LabelBinarizer().fit(y_train)
y_onehot_test = label_binarizer.transform(y_test)
y_onehot_test.shape  # (n_samples, n_classes)
# Out:
# (890, 4)

# %%
class_of_interest = 0
class_id = np.flatnonzero(label_binarizer.classes_ == class_of_interest)[0]
class_id
# Out:
# 0

# %%
from sklearn.metrics import roc_curve, auc

# store the fpr, tpr, and roc_auc for all averaging strategies
fpr, tpr, roc_auc = dict(), dict(), dict()
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_onehot_test.ravel(), y_score.ravel())
#precision["micro"], recall["micro"], _ = roc_curve(y_onehot_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{roc_auc['micro']:.2f}")
# Out:
# Micro-averaged One-vs-Rest ROC AUC score:
# 0.99

# %%
from sklearn.metrics import RocCurveDisplay
n_classes=4
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_onehot_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fpr_grid = np.linspace(0.0, 1.0, 1000)

# Interpolate all ROC curves at these points
mean_tpr = np.zeros_like(fpr_grid)

for i in range(n_classes):
    mean_tpr += np.interp(fpr_grid, fpr[i], tpr[i])  # linear interpolation

# Average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = fpr_grid
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

print(f"Macro-averaged One-vs-Rest ROC AUC score:\n{roc_auc['macro']:.2f}")
# Out:
# Macro-averaged One-vs-Rest ROC AUC score:
# 0.95

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import RocCurveDisplay

from itertools import cycle

fig, ax = plt.subplots(figsize=(6, 6))

plt.plot(
    fpr["micro"],
    tpr["micro"],
    label=f"micro-average ROC curve (AUC = {roc_auc['micro']:.2f})",
    color="deeppink",
    linestyle=":",
    linewidth=4,
)

plt.plot(
    fpr["macro"],
    tpr["macro"],
    label=f"macro-average ROC curve (AUC = {roc_auc['macro']:.2f})",
    color="navy",
    linestyle=":",
    linewidth=4,
)

colors = cycle(["aqua", "darkorange", "cornflowerblue", "darkgreen"])
for class_id, color in zip(range(n_classes), colors):
    RocCurveDisplay.from_predictions(
        y_onehot_test[:, class_id],
        y_score[:, class_id],
        name=f"ROC curve for {class_id}",
        color=color,
        ax=ax,
    )

plt.plot([0, 1], [0, 1], "k--", label="ROC curve for chance level (AUC = 0.5)")
plt.axis("square")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Extension of Receiver Operating Characteristic\nto One-vs-Rest multiclass")
plt.legend()
plt.show()

# %%
from sklearn.metrics import precision_recall_curve, roc_curve
n_classes=4
precision = dict()
recall = dict()
for i in range(n_classes):
    precision[i], recall[i], _ = precision_recall_curve(y_onehot_test[:, i],y_score[:, i])
    plt.plot(recall[i], precision[i], lw=2, label='class {}'.format(i))
    
plt.xlabel("recall")
plt.ylabel("precision")
plt.legend(loc="best")
plt.title("precision vs. recall curve")
plt.show()
